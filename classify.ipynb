# %%
import json
from pprint import pprint
from dateutil import parser
from bs4 import BeautifulSoup
from pysurvey.plot import setup, line, legend, box, dateticks
from matplotlib.dates import date2num

# %%
data = json.load(open('faculty_2014.json'))
# data = json.load(open('postdoc_2014.json'))

# %%
len(data), type(data), np.array(data[0].keys())
# Out:
# (26,
#  list,
#  array([u'comment', u'newver', u'oldver', u'version', u'user', u'date',
#        u'preview', u'changes'],
#       dtype='<U7'))

# %%
np.array([x.get('newver', 0) for x in data])
# Out:
# array([627, 628, 629, 630, 631, 632, 633, 634, 635, 636, 637, 638, 639,
#        640, 641, 642, 643, 644, 645, 646, 647, 648, 649, 651, 652, 653])

# %%
dates = np.array([parser.parse(x['date']) for x in data])
changes = np.array([len(x['comment']) for x in data])
changes = np.array([len(x['changes']) for x in data])

# %%
setup(figsize=(12,12))
plot(date2num(dates),changes, 's')
dateticks()

# %%
def parse_preview_table(s):
    header = []
    rows = []
    for i, tr in enumerate(s.find_all('tr')):
        if i == 0:
            # it is not clear if i need this since 
            # they are special th values
            for th in tr.find_all('th'):
                header.append(th.text.strip())
        else:
            tmp = []
            
            # populate the links
            for a in tr.find_all('a'):
                a.insert_after('[{} {}]'.format(a['href'], a.text.strip())
                                        .replace('a ] d','ad]'))
                a.extract()
            
            # populate the bolded people
            for strong in tr.find_all('strong'):
                strong.insert_after(u'*{}*'.format(strong.text.strip()))
                strong.extract()
            
            # Get the columns of the row
            tmp.extend([' '.join(td.text.strip()
                                   .replace('(          )','')
                                   .split())
                        for td in tr.find_all('td')])
            
            # create a simple tag for the intro
            tmp.insert(0,tmp[0].split('(')[0].strip())
            
            rows.append(tmp)
    return header, rows

def get_title(soup):
    try:
        # crawl up the tree ten times.
        for i in range(10):
            s = soup.previous_element.strip()
            if len(s) > 0:
                return s
            else:
                soup = soup.previous_element
    except Exception as e:
        print e
        return 'No Title found'
    
    
def parse_preview_faculty(soup):
    for s in soup.find_all('table',{'class':'wikitable'}):
        print '-'*40
        print get_title(s)
        print '-'*40
        header, rows = parse_preview_table(s)
        print header
        pprint(rows[:])

#         print header
#         break
#     print soup.prettify()

soup = BeautifulSoup(data[-1]['preview'])
parse_preview_faculty(soup)
# Out:
# ----------------------------------------
# Tenure Track Faculty Positions
# ----------------------------------------
# [u'Place/Institution (alphabetical)', u'People (in boldface if accepted)']
# [[u'Academia Sinica',
#   u'Academia Sinica ( [http://jobregister.aas.org/job_view?JobID=46354 ad] )',
#   u'Due 25 January 2014. Applications are still under review. No decisions made yet.'],
#  [u'Aix-Marseille University',
#   u'Aix-Marseille University ( [http://amidex.univ-amu.fr/en/2014-rising-stars-call-for-applications ad] )',
#   u'*Matthew Pieri*'],
#  [u'SUNY Albany',
#   u'SUNY Albany ( [http://inspirehep.net/record/1261825 ad] )',
#   u'Shortlist made, includes Mark Wyman, Matthew Szydagis. Offer made to *Matthew Szydagis* .'],
#  [u'SUNY Oneonta',
#   u'SUNY Oneonta ( [http://oneonta.interviewexchange.com/jobofferdetails.jsp?JOBID=49047 ad] )',
#   u'Applications open now (May 12) for a short time.'],
#  [u'Amherst College',
#   u'Amherst College ( [http://jobregister.aas.org/job_view?JobID=45305 ad] )',
#   u'due Nov 15, 2013; interviews being scheduled. Shortlist includes: Jessica Werk, Daryl Haggard, Alison Crocker, and Aleks Diamond-Stanic. Offer made to *Daryl Haggard and Nick Cowan* .'],
#  [u'Amsterdam, 2 positions',
#   u'Amsterdam, 2 positions ( [http://jobregister.aas.org/job_view?JobID=47948 ad] )',
#   u'due May 15 2014. Interview dates are 06/30, 07/02, 07/03, 07/09 2014. Candidates contacted. Some rejection letters send. At least some shortlist candidates notified. Shortlist includes: Thomas Janka, Yamila Miguel, Sascha Quanz, Amaury Triaud, Jayne Birkby, Jean-Michel Desert'],
#  [u'Universidad Andres Bello',
#   u'Universidad Andres Bello ( [http://jobregister.aas.org/job_view?JobID=47958 ad] )',
#   u'Interviews being scheduled. Shortlist includes Mederic Boquien.'],
#  [u'University of Arizona',
#   u'University of Arizona (Theoretical Astrophysics, [http://tap.arizona.edu/opportunities ad] )',
#   u'Review begins December 2013; no hard deadline; some rejections sent; some reference letters requested. Shortlist includes Jennifer Siegal-Gaskins, James Owen, Rebecca Martin, Shunsaku Horiuchi, Sean Couch.'],
#  [u'University of Arizona',
#   u'University of Arizona (Experimental Particle Astrophysics or Experimental Cosmology, [http://inspirehep.net/record/1253480 ad] )',
#   u'due Dec 15, 2013; Shortlist includes: Matthew Szydagis, Bradford Benson, *Eduardo Rozo* .'],
#  [u'Arkansas Tech University',
#   u'Arkansas Tech University',
#   u'Offer made to *Amber Sierra*'],
#  [u'University of Birmingham, UK',
#   u'University of Birmingham, UK',
#   u'Shortlist made. Boilerplate rejection letter sent. Interviews being scheduled. Offers made to *Sean McGee* and Nicolas Smith-Lefebvre.'],
#  [u'Boise State',
#   u'Boise State ( [http://hrs.boisestate.edu/careers/searchcareers/observational-astronomerastronomy-educator/ ad] )',
#   u'Due Dec 31 2013; Phone interviews scheduled, including David Syphers and Eric Thrane. Shortlist includes David Syphers. Offer made to *Brian Jackson* (3/10).'],
#  [u'Cal Poly Pomona',
#   u'Cal Poly Pomona ( [http://jobregister.aas.org/node/45329 ad] )',
#   u'Offer made to *Jorge Moreno*'],
#  [u'Cal Poly, San Luis Obispo',
#   u'Cal Poly, San Luis Obispo',
#   u'Offers made to *Steve Drasco* and *others*'],
#  [u'Caltech',
#   u'Caltech ( [http://jobregister.aas.org/job_view?JobID=45077 ad] )',
#   u'*! Mansi Kasliwal* and *Evan Kirby* and *Dimitri Mawet !*'],
#  [u'Caltech',
#   u'Caltech (planetary science)',
#   u'Some interviews scheduled, including Alyssa Rhoden.'],
#  [u'University of Central Florida',
#   u'University of Central Florida (planetary science, [https://www.jobswithucf.com/postings/38215 ad] )',
#   u'1-2 positions, junior or senior, related broadly to surfaces of asteroids, the moon, and planets/exoplanets, including regoliths, microgravity, impacts, orbits, theory, observation, instruments. Some letters solicited, search still open. any news?'],
#  [u'Clemson University',
#   u'Clemson University',
#   u'Offer made to *Marco Ajello*'],
#  [u'CNAP, France',
#   u'CNAP, France',
#   u'*John Carter, Mickael Coriat, Orlagh Creevey, Benjamin Godard, Sophie Masson, Ada Nebot Gomez-Moran*'],
#  [u'CNRS, France',
#   u'CNRS, France',
#   u'CR2 : *Fabio ACERO* (AIM), *Nathalie YSARD* (IAS), *Micka\xebl BONNEFOY* (IPAG), *Aur\xe9lie* *GUILBERT-LEPOUTRE* (UTINAM). CR1 : *Yohan DUBOIS* (IAP). DR2 : *Guillaume Dubus* , *Bertrand Lefloch* , *Marc Antoine Miville-Desch\xeanes* , *Franck Selsis* , *Olivier Forni* , *Delphine Porquet* , *Alexandre Marcowith* , *Karine Issautier*'],
#  [u'Colby College', u'Colby College', u'Offer made to *Dale Kocevski*'],
#  [u'College of Southern Nevada',
#   u'College of Southern Nevada ( [http://jobs.csn.edu/applicants/Central?quickFind=52903 ad] )',
#   u'Planetarium manager. Apply by March 16, 2014.'],
#  [u'College of Southern Nevada',
#   u'College of Southern Nevada ( [http://jobs.csn.edu/applicants/Central?quickFind=52895 ad] )',
#   u'Full-time, tenure track astronomy/physics instructor. Applications accepted until the position is filled for faculty position. Apply by March 14, 2014, for full consideration. Short list made, interviews being scheduled (almost).'],
#  [u'CUNY-Borough of Manhattan Community College',
#   u'CUNY-Borough of Manhattan Community College ( [https://home.cunyfirst.cuny.edu/psp/cnyepprd/GUEST/HRMS/c/HRS_HRAM.HRS_CE.GBL ad] ) (CUNY Job ID: 9284). For more information contact bmckernan or sford AT amnh.org',
#   u'First-round interviews being scheduled.'],
#  [u'CUNY-Bronx Community College',
#   u'CUNY-Bronx Community College ( [https://home.cunyfirst.cuny.edu/psp/cnyepprd/GUEST/HRMS/c/HRS_HRAM.HRS_CE.GBL?Page=HRS_CE_JOB_DTL&Action=A&JobOpeningId=9905&SiteId=1&PostingSeq=1 ad] , Job ID 9905)',
#   u'Due Feb 28.'],
#  [u'CUNY-City Tech',
#   u'CUNY-City Tech ( [https://home.cunyfirst.cuny.edu/psp/cnyepprd/GUEST/HRMS/c/HRS_HRAM.HRS_CE.GBL?Page=HRS_CE_JOB_DTL&Action=A&JobOpeningId=9894&SiteId=1&PostingSeq=1 ad] , Job ID 9894)',
#   u'Applications will be accepted until the position is filled. Review of resumes will begin 1/28/14.'],
#  [u'CUNY-Hunter College',
#   u'CUNY-Hunter College ( [https://home.cunyfirst.cuny.edu/psp/cnyepprd/GUEST/HRMS/c/HRS_HRAM.HRS_CE.GBL?Page=HRS_CE_JOB_DTL&Action=A&JobOpeningId=9985&SiteId=1&PostingSeq=1 ad] , Job ID 9985)',
#   u'The committee will begin reviewing applications on February 10, 2014. The search will remain open until the position is filled.'],
#  [u'Universidad de Chile',
#   u'Universidad de Chile ( [http://jobregister.aas.org/node/44607 ad] )',
#   u'offer made to *Guillermo Blanc*'],
#  [u'Universidad de Chile',
#   u'Universidad de Chile ( [http://jobregister.aas.org/node/46614 ad] )',
#   u'two offers made'],
#  [u'The University of Chicago',
#   u'The University of Chicago (Astrophysics, [http://jobregister.aas.org/job_view?JobID=45699 ad] )',
#   u'Shortlist of 7, includes George Becker, Laura Lopez, Adam Leroy, Jo Bovy'],
#  [u'The University of Chicago',
#   u'The University of Chicago (Gravity/Cosmo)',
#   u'Shortlist includes S am Gralla, Kurt Hinterbichler, Marilena LoVerde , Vasileios Paschalidis, Rafael Porto, Aron Wall'],
#  [u'Universidad de Concepci\xf3n',
#   u'Universidad de Concepci\xf3n (Senior Professor)',
#   u'Offer made to Brad Gibson (Feb 3, declined).'],
#  [u'Universidad de Concepci\xf3n',
#   u'Universidad de Concepci\xf3n (Tenure-Track, [http://jobregister.aas.org/job_view?JobID=47321 ad] )',
#   u'Reference letters requested (Feb 18). Offer made.'],
#  [u'Curtin University',
#   u'Curtin University (senior lecturer astronomy, [https://webkiosk.curtin.edu.au/pls/prd/WK8127$APP.draw_attachments?P_VACANCY_REF_NO=3065&P_CALLER_URL=WK8127ZZDOLLARZZAPP.QueryListZZQMARKZZZ_VACANCY_CAT=ACADZZAMPZZZ_ORDER_BY=1 ad] )',
#   u'due Jan 13, 2014. Shortlist made, interviews being scheduled, some rejections sent. Shortlist includes Jean-Pierre Macquart, *James Miller-Jones* , *Nick Seymour* .'],
#  [u'University College Dublin, UCD School of Physics, Dublin, Ireland',
#   u'University College Dublin, UCD School of Physics, Dublin, Ireland (EU) ( [http://www.ucd.ie/hr/jobvacancies/ ad1] , [http://www.nature.com/naturejobs/science/jobs/398703-lecturer-asst-prof-in-astrophysics-and-space-science ad2] )',
#   u'Lecturer (Asst Prof, permanent, full time) in Astrophysics and Space Science. Closing date *April 11, 2014*. Interviews to be held during the week of May 5-9, 2014.'],
#  [u'Federal University of Rio de Janeiro',
#   u'Federal University of Rio de Janeiro (UFRJ, 3 positions)',
#   u'offers made to *Thiago S Goncalves* (extragalactic, obs. cosmology) *, Adrian Rodriguez Colucci* (celestial mechanics) *,* Wladimir Lyra (planetary, ISM, astrochemistry)'],
#  [u'Florida Atlantic University',
#   u'Florida Atlantic University (2 positions, [http://hyperspace.aei.mpg.de/2014/01/03/two-faculty-positions-in-gravity-at-florida-atlantic-university/ ad)]',
#   ''],
#  [u'Florida Institute of Technology',
#   u'Florida Institute of Technology (Space Physics, [http://jobregister.aas.org/job_view?JobID=46483 ad] )',
#   u'due Jan 1, 2014. Offer made to Ofer Cohen.'],
#  [u'Florida Institute of Technology',
#   u'Florida Institute of Technology (Star/Planet Formation, [http://jobregister.aas.org/job_view?JobID=46483 ad] )',
#   u'Skype interviews being scheduled, including Wlad Lyra.'],
#  [u'Georgia Southern University',
#   u'Georgia Southern University',
#   u'Offered to Jeyhan Kartaltepe (declined). Position is closed.'],
#  [u'Georgia State',
#   u'Georgia State (astroinformatics/exoplanet/stellar, [http://jobregister.aas.org/node/45546 ad] )',
#   ''],
#  [u'Georgia Tech',
#   u'Georgia Tech (observational/experimental; [http://jobregister.aas.org/job_view?JobID=45774 ad] )',
#   u'due Dec. 1, 2013; shortlist made'],
#  [u'Grinnell College',
#   u'Grinnell College (physics; [https://jobs.grinnell.edu/postings/576 ad] )',
#   u'*Charlotte Christensen*'],
#  [u'University of Hull, UK',
#   u'University of Hull, UK',
#   u'Interviews held, shortlist of 9 including Richard Bielby & *Kevin Pimbblet.*'],
#  [u'Harvard University',
#   u'Harvard University ( [http://jobregister.aas.org/node/45450 ad] )',
#   u'Shortlist of 6 made, including Caitlin Casey, Kate Rubin, Pascal Oesch, Charlie Conroy; interviews scheduled. Offers made: *Charlie Conroy* , Mariska Kriek'],
#  [u'Instituto de Fisica de Sao Carlos',
#   u'Instituto de Fisica de Sao Carlos ( [http://www.ifsc.usp.br/index.php?option=com_content&view=article&id=1833:concurso-professor-doutor-edital-atacifsc-312013-ffi&catid=31:concursos-encerrados&Itemid=225 ad] )',
#   u'Offer made to Manuela Vecchi'],
#  [u'Johns Hopkins University',
#   u'Johns Hopkins University (data intensive astrophysics, [https://apply.interfolio.com/23601 ad] )',
#   u'due Jan 1, 2014. Interviews being scheduled. Shortlist includes Josh Peek, Cora Dvorkin, Tamas Budavari, Matt Turk'],
#  [u'Kavli Institute for Astronomy and Astrophysics, Peking University',
#   u'Kavli Institute for Astronomy and Astrophysics, Peking University',
#   u'shortlist made. Rejection letters sent.'],
#  [u'University of Kent, 2 positions',
#   u'University of Kent, 2 positions ( [http://www.jobs.ac.uk/job/AIG102/lecturer-in-physics-x2/ ad] )',
#   u'due Apr 6, 2014. Interviews to be held on Apr 30, 2014. Shortlist includes Katja Poppenhaeger, Penny Wozniakiewicz, Dmitry Sokolov, Aglae Kellerer. Offer made to Katja Poppenhaeger (declined).'],
#  [u'University of KwaZulu-Natal',
#   u'University of KwaZulu-Natal ( [https://jobregister.aas.org/job_view?JobID=45948 ad] )',
#   u'due Dec 1, 2013'],
#  [u'KU Leuven',
#   u'KU Leuven ( [http://www.astroscu.unam.mx/massive_stars/jobs/2014/14022887771.htm ad] )',
#   u'due May 22, 2014. Shortlist includes Katja Poppenhaeger.'],
#  [u'Macquarie Univ. / CSIRO Astronomy and Space Science',
#   u'Macquarie Univ. / CSIRO Astronomy and Space Science (joint ongoing position in astrophysics, [http://jobregister.aas.org/job_view?JobID=46376 ad] )',
#   u'Some interviews scheduled including Josh Peek Some rejections sent (2/26) Offers made to Josh Peek, *Jo Dawson*'],
#  [u'University of Manchester',
#   u'University of Manchester ( [https://www.jobs.manchester.ac.uk/displayjob.aspx?jobid=7322 ad] )',
#   u'Interviews 7/8 July, 2014. Shortlist: Filipe Abdalla, Anna Bonaldi, Rene Breton, Geraint Harker, George Heald, Katie Mack, Garrelt Mellema, Jonathan Pritchard, Mario Santos.'],
#  [u'Michigan State University',
#   u'Michigan State University (Physics or astronomy, [http://www.lymanbriggs.msu.edu/faculty/Fall-2013-Assistant-Professor-Physics.pdf ad] ). Note: job is also open to observational astronomers!',
#   u'due Nov 1, 2013; shortlist of 6 including 3 astronomers; some rejections sent'],
#  [u'University of Michgan',
#   u'University of Michgan (joint position in Biophysics and Astronomy, [http://jobregister.aas.org/job_view?JobID=45502 ad] )',
#   u'Due Nov 1, 2013'],
#  [u'University of Mississippi',
#   u'University of Mississippi ( [http://hyperspace.aei.mpg.de/2013/10/24/faculty-position-in-physics-at-the-university-of-mississippi/ ad] )',
#   u'Interviews underway'],
#  [u'Missouri State University, Springfield',
#   u'Missouri State University, Springfield ( [http://jobregister.aas.org/node/46429 ad] )',
#   u'due Dec. 1, 2013; shortlist of 4 made. Offer made to *Peter Plavchan* .'],
#  [u'MIT',
#   u'MIT (Astrophysics, [http://jobregister.aas.org/job_view?JobID=45661 ad] )',
#   u'Target-of-opportunity offer made to Mansi Kasliwal in November (separate from regular search). Shortlist made, including Laura Lopez, Mike McDonald, David Tsang, Sebastiano Cantalupo, Xin Liu. Offer made, declined.'],
#  [u'Monash University',
#   u'Monash University (Astronomy or Physics, [http://jobs.monash.edu.au/jobDetails.asp?sJobIDs=517825 ad] )',
#   u'Rejection emails sent (July 18)'],
#  [u'Morehead State University',
#   u'Morehead State University (Tenure Track) ( [http://www.higheredjobs.com/faculty/details.cfm?JobCode=175858877&Title=Assistant%20Professor%20of%20Astrophysics/Space%20Science ad] )',
#   u'Review of applications begins on March 24th.'],
#  [u'Mount Allison University',
#   u'Mount Allison University (Tenure Track)',
#   u'Shortlist made (Feb 21). Have all been notified? Incl. Tyler Foster. Skype interviews for most/all shortlisted Feb. 24; 1-2 candidates to be interviewed on campus in march-april. Offer made and accepted.'],
#  [u'MPA',
#   u'MPA (Director, [http://jobregister.aas.org/job_view?JobID=45256 ad] )',
#   u'due Sep 15, 2013'],
#  [u'MPE Senior Staff',
#   u'MPE Senior Staff (Tenure Track) ( [http://jobregister.aas.org/job_view?JobID=46310 ad] )',
#   u'long list made (shortlist ?).'],
#  [u'Univ. of Nevada, Las Vegas',
#   u'Univ. of Nevada, Las Vegas ( [http://jobregister.aas.org/job_view?JobID=45586 ad] )',
#   u'Shortlist includes: Marcelo Alvarez, Kayhan Gultekin, Raffaella Margutti, Rebecca Martin, Ryan Chornock. Offer made to *Rebecca Martin* .'],
#  [u'Newcastle University',
#   u'Newcastle University',
#   u'due April 22 2014, shortlist includes: Cristiano Germani, interviews held week 19-23 May'],
#  [u'University of North Carolina',
#   u'University of North Carolina ( [https://unc.peopleadmin.com/postings/32613 ad] )',
#   u'Shortlist includes Sam Gralla, Chiu Man Ho, John Joseph Carrasco, Tanja Hinderer and at least one more senior person (inferred from seminar schedule).'],
#  [u'University of Oklahoma',
#   u'University of Oklahoma ( [http://nhn.ou.edu/~baron/ad.html ad] )',
#   u'Shortlist inferred from colloquium schedule: Mark Neyrinck, Vasilis Paschalidis, *Nathan Kaib* , Jason Dexter, Rodrigo Fernandez'],
#  [u'Ohio State University',
#   u'Ohio State University ( [http://jobregister.aas.org/job_view?JobID=46010 ad] )',
#   u'Interviews scheduled for Feb-Mar. Shortlist includes: Thayne Currie, David Law, Adam Leroy, Laura Lopez, Rebecca Martin, Andrew Skemer. Offers made to *Laura Lopez* and *Adam Leroy.*'],
#  [u'Ohio University',
#   u'Ohio University ( [http://jobregister.aas.org/job_view?JobID=45401 ad] )',
#   u'Shortlist includes Jeyhan Kartaltepe, Sharon Meidt, and Ryan Chornock. Offer made to *Ryan Chornock* .'],
#  [u'Pennsylvania State University',
#   u'Pennsylvania State University (Physics) ( [http://www.phys.psu.edu/jobs/news ad] )',
#   u'Shortlist made, includes: Bradford Benson, Kohta Murase, Karen Gibson. Offers made and *accepted* : *Kohta Murase* (joint w. Astronomy & Astrophysics) and Bradford Benson.'],
#  [u'Rennselaer Polytechnic Institute',
#   u'Rennselaer Polytechnic Institute (particle astrophysics) ( [http://www.rpi.edu/dept/phys/faculty/Assistant_Prof_Physics001706.pdf ad] )',
#   u'due Oct 20, 2013; Offer made and accepted.'],
#  [u'Rice University',
#   u'Rice University (star/planet formation) ( [http://jobregister.aas.org/job_view?JobID=46048 ad] )',
#   u'Long and short-list made, some rejections sent. Interviews being scheduled (1/31); short list includes Jason Steffen, John Tobin. Offer made to *Andrea Isella* .'],
#  [u'Shanghai Astronomical Observatory',
#   u'Shanghai Astronomical Observatory ( [http://jobregister.aas.org/node/43419 ad] ), (2012-2013 search)',
#   u'Decisions were delayed. Offer made to Chun Ly (declined)'],
#  [u'Southampton',
#   u'Southampton ( [http://www.astro.soton.ac.uk/vacancies.html ad] )',
#   u'Shortlist drawn up and selected candidates invited to interview at the end of March (2/26). Rejection letters sent. Shortlist includes: Rodrigo Fernandez; Adam Hill; Simone Scaringi. Interviews held Mar 24/25. Offers made and *accepted* (including Gandhi, Hoenig).'],
#  [u'Stony Brook',
#   u'Stony Brook (Observational Astronomy) ( [https://academicjobsonline.org/ajo/jobs/2801 ad] )',
#   u"Invitations sent, interviews scheduled, including Carrie Bridge, Jonathan Foster, Jens Kauffmann, Jan Forbrich, Jeyhan Kartaltepe, and Jackie Faherty. 'Letters of regret' sent out. Offer made and accepted"],
#  [u'Stony Brook',
#   u'Stony Brook (Cosmology - 2 positions, theory and observation) ( [http://academicjobsonline.org/ajo/jobs/3319 ad] )',
#   u'Shortlist made. Invitations sent. Theory list appears to include Marilena LoVerde, Rafael Porto, Jaiyul Yoo (from seminar schedule). Offers made to *Marilena LoVerde* and Anja von der Linden.'],
#  [u'STScI',
#   u'STScI ( [http://jobregister.aas.org/job_view?JobID=45403 ad] )',
#   u'Shortlist made. In person interviews in progress. Offers made to *Josh Peek, Molly Peeples, Nikole Lewis, George Becker.* Other offers pending.'],
#  [u'University of Surrey',
#   u'University of Surrey ( [http://jobregister.aas.org/job_view?JobID=47819 ad] )',
#   u'due Apr 30, 2014. Some rejection letters sent by email advising that candidates had not been shortlisted (May 10). More rejection letters sent on May 22. Shortlist of 5 includes Sean Farrell. Second round interviews took place on 19th/20th June. Offer made and accepted.'],
#  [u'Texas A&M University',
#   u'Texas A&M University (2 positions) ( [http://jobregister.aas.org/job_view?JobID=45760 a] [http://jobregister.aas.org/job_view?JobID=45760 d] )',
#   u'about 200 applications received, initial review underway (1/22). Reference letters requested (1/30), phone interviews underway (3/7). Some rejections sent (3/26). Campus visits scheduled, including Wenjuan Fang (3/28). Offers made.'],
#  [u'Texas A&M University - Mitchell Institute Director',
#   u'Texas A&M University - Mitchell Institute Director ( [http://jobregister.aas.org/job_view?JobID=45753 ad] )',
#   u'due Jan 1, 2014'],
#  [u'Texas A&M University-Commerce',
#   u'Texas A&M University-Commerce ( [http://jobregister.aas.org/job_view?JobID=45191 ad] )',
#   u'Offer made to *Robynne Lock*'],
#  [u'Texas Christian University',
#   u'Texas Christian University ( [http://jobregister.aas.org/job_view?JobID=46133 ad] )',
#   u'due Feb 1, 2014; some reference letters requested (2/10), some rejections sent (3/1). Offer made to *Kat Barger* .'],
#  [u'Texas Tech University',
#   u'Texas Tech University ( [http://jobregister.aas.org/job_view?JobID=45937 ad] )',
#   u'due Dec 1, 2013; long list made, official notice soon to come; some rejections sent; Offer made to Daryl Haggard.'],
#  [u'UCLA theoretical/computational plasma physics',
#   u'UCLA theoretical/computational plasma physics ( [http://www.pa.ucla.edu/sites/default/files/files/open_positions/plasma.pdf ad] )',
#   u'Shortlist made.'],
#  [u'UCR Theoretical Studies of the Early Universe',
#   u'UCR Theoretical Studies of the Early Universe ( [http://jobregister.aas.org/job_view?JobID=46330 ad] )',
#   u'Shortlist includes Laura Sales, Ben Oppenheimer, Robert Feldmann, Andrew Wetzel, Chris Hayward. Offer made to *Laura Sales* .'],
#  [u'UCSB theoretical astrophysics or high-energy physics',
#   u'UCSB theoretical astrophysics or high-energy physics ( [http://jobs.physicstoday.org/jobs/5653231/tenure-track-faculty-position ad] )',
#   u'due Nov 20, 2013; Shortlist made, includes Jo Bovy, Robert Feldmann, Matthew Kunz, Ruth Murray-Clay, and two high-energy candidates. Offer made to *Nathaniel Craig* (HEP)'],
#  [u'UCSC Planetary',
#   u'UCSC Planetary ( [http://eps.ucsc.edu/about/JPF00057-14-1.pdf ad] )',
#   u'Shortlist: Matija Cuk, Joseph Michalski, Jonathan Mitchell, Kevin Walsh, Xi Zhang. Offer made.'],
#  [u'UCSD Astrophysics/Astronomy',
#   u'UCSD Astrophysics/Astronomy ( [http://academicaffairs.ucsd.edu/aps/adeo/recruitment/jobdetails.asp?PositionNumber=10-644 ad] )',
#   u'Shortlist: Karin Sandstrom, Laura Lopez, Sarah Miller, Kate Rubin, Jennifer Siegal-Gaskins. Ranked list made. Offers made to *Karin Sandstrom* and *Quinn Konopacky* .'],
#  [u'UCSD Experimental Astrophysics',
#   u'UCSD Experimental Astrophysics ( [https://academicaffairs.ucsd.edu/aps/adeo/recruitment/jobdetails.asp?PositionNumber=10-641 ad] )',
#   u"Shortlist made, includes: Bradford Benson, Roger O'Brient, Naoko Neilson. Offer made to *Shelley Wright* ."],
#  [u'University of Colorado, Boulder',
#   u'University of Colorado, Boulder (Solar Physics) ( [http://jobregister.aas.org/job_view?JobID=45944 ad] )',
#   u'shortlist includes: Paul Cassak, Steven Cranmer, Wei Liu, Savita Mathur, Franco Rappazzo, Nicholeen Viall. Offer made to Paul Cassak, declined.'],
#  [u'UFRGS',
#   u'UFRGS (Porto Alegre, Brasil, [http://www.ufrgs.br/progesp/progesp-1/concursos-publicos/magisterio-superior/concuros/2013/edital-11-2013 ad] )',
#   u'Offer made to *Alan Brito*'],
#  [u'UNAM - Instituto de Astronom\xeda',
#   u'UNAM - Instituto de Astronom\xeda (Mexico City, Mexico, [http://jobregister.aas.org/node/46326 ad] )',
#   u'One or two junior position(s): shortlist made. Interviews underway. Offers expected in 2-3 weeks. Offer made to *Maritza A. Lara-Lopez* (6 March), 2nd Offer made and *accepted (3/14)* , *Yilen Gomez Maqueo Chew* (5 March).'],
#  [u'University of Illinois at Urbana-Champaign',
#   u'University of Illinois at Urbana-Champaign (Observational Cosmology) ( [http://careers.aps.org/jobs/5720580/faculty-position-exp-or-observational-cosmology-exp-particle-physics ad] )',
#   u'due Dec 1, 2013. Shortlist includes: Bradford Benson, Jeffrey Filippini, Marcelle Soares-Santos. Offer to Bradford Benson, Jeffrey Filippini.'],
#  [u'University Paris 6',
#   u'University Paris 6 (Euclid position, [https://www.galaxie.enseignementsup-recherche.gouv.fr/ensup/ListesPostesPublies/ANTEE/2014_1/0751722P/FOPC_0751722P_4250.pdf ad] )',
#   u'Rejection letters sent. Shortlist includes: Aurelien Benoit-Levy'],
#  [u'Universidade de Sao Paulo',
#   u'Universidade de Sao Paulo (Instituto de Astronomia )',
#   u'Offer made to *Rodrigo Nemmen*'],
#  [u'University of Tampa',
#   u'University of Tampa ( [http://jobregister.aas.org/job_view?JobID=46109 ad] )',
#   u'due Jan 1, 2014 (Nov 30 deadline on JR is incorrect); Offer made and accepted.'],
#  [u'University of Texas at Austin',
#   u'University of Texas at Austin',
#   u'*Caitlin Casey* (starting Fall 2015)'],
#  [u'University of Toronto',
#   u'University of Toronto ( [http://jobregister.aas.org/node/45860 ad] )',
#   u'Some Skype interviews scheduled; shortlist made, including Jo Bovy, Laura Lopez, Adam Muzzin, Stijn Wuyts. Campus visits ongoing. Offers made.'],
#  [u'University of Valpara\xedso',
#   u'University of Valpara\xedso (Chile, [http://dfa.uv.cl/index.php?option=com_content&view=article&id=220:llamado-urgente-concurso-publico&catid=75:noticias&Itemid=119&lang=en ad] )',
#   u'Shortlist made, including Mederic Boquien'],
#  [u'University of Virginia theoretical astrophysics',
#   u'University of Virginia theoretical astrophysics ( [https://jobs.virginia.edu/applicants/jsp/shared/frameset/Frameset.jsp?time=1388765034770 ad] )',
#   u'shortlist includes: Shane Davis, Joshua Dolence, Matthew Kunz, Emily Rauscher, Kevin Schlaufman. Offer made to *Shane Davis*'],
#  [u'UVa Chemistry/Astronomy',
#   u'UVa Chemistry/Astronomy ( [http://jobregister.aas.org/job_view?JobID=45626 ad] )',
#   u'due Oct 31, 2013. Interviews mid-Jan to late Feb. Shortlist of six: Stefan Andersson, Kyle Crabtree, Rob Garrod, Sergio Ioppolo, Ruud Visser, Nadine Wehres. Offer made to Rob Garrod (April 11).'],
#  [u'Ventura College',
#   u'Ventura College (VCCCD)',
#   u'Shortlist includes Wlad Lyra'],
#  [u'Victoria University of Wellington',
#   u'Victoria University of Wellington (NZ)',
#   u'Offer made to Steve Curran, 30th May 2014'],
#  [u'Virginia Tech',
#   u'Virginia Tech (Cosmology) ( [https://listings.jobs.vt.edu/postings/42457 ad] )',
#   u'Shortlist made, including Jeyhan Kartaltepe, Kurt Hinterbichler, Carrie Bridge, Shunsaku Horiuchi, Jean-Luc Lehners. Offer made to Carrie Bridge, *Shunsaku Horiuchi*'],
#  [u'University of Washington',
#   u'University of Washington (LSST) ( [https://chroniclevitae.com/jobs/0000819981-01 ad] )',
#   u'Due April 15, 2014'],
#  [u'Western Washington University',
#   u'Western Washington University ( [http://jobregister.aas.org/node/45491 ad] )',
#   u'One offer made and *accepted* .'],
#  [u'UC Berkeley Astroparticle',
#   u'UC Berkeley Astroparticle ( [https://aprecruit.berkeley.edu/apply/JPF00197 ad)]',
#   u'due Nov 8, 2013; Short list includes Blair Edwards, Jeffrey Filippini, Hugh Lippincott, Karen Gibson; Offer to senior candidate'],
#  [u'Uppsala University, 10 positions in any science/technology',
#   u'Uppsala University, 10 positions in any science/technology ( [http://jobs.hipeac.net/job/10-tenure-track-assistant-professor-positions-science-and-technology-uppsala-university ad] )',
#   u'Offers to Pat Scott, Erik Zackrisson'],
#  [u'York University Tier 2 CRC in theoretical cosmology/particle physics',
#   u'York University Tier 2 CRC in theoretical cosmology/particle physics ( [https://academicjobsonline.org/ajo/jobs/3266 ad] )',
#   u'due Dec 10, 2013; Shortlist includes Brian Batell']]
# ----------------------------------------
# Science Staff and Management Positions
# ----------------------------------------
# [u'Place/Institution (alphabetical)', u'People (in boldface if accepted)']
# [[u'AURA, President',
#   u'AURA, President ( [http://www.aura-astronomy.org/news/President/solicitation%20announcement_20131216.pdf ad] )',
#   u'due by 1 May 2014'],
#  [u'ESO, Director for Science',
#   u'ESO, Director for Science',
#   u'offer made, Council approval sought; *Rob Ivison* appointed'],
#  [u'LCO Director', u'LCO Director', u'short list includes Dante Minniti'],
#  [u'University of Hawaii',
#   u'University of Hawaii (Manoa), Researcher ( [http://jobregister.aas.org/node/45621 ad] )',
#   u'position cancelled'],
#  [u'Paris Observatory, Director LERMA2',
#   u'Paris Observatory, Director LERMA2',
#   u'invited for interviews: M. Gerin, *D. Lis* , R. Mauersberger'],
#  [u'Space Science Institute, Executive Director',
#   u'Space Science Institute, Executive Director ( [http://www.spacescience.org http://www.spacescience.org] )',
#   u'due end of Jan 2014. Offer made.'],
#  [u'NASA Exoplanet Science Institute',
#   u'NASA Exoplanet Science Institute (NExScI) Exoplanet Archive Scientist ( [https://jobregister.aas.org/job_view?JobID=48249 ad] )',
#   u'due July 1, 2014'],
#  [u'NCSA, Research Scientist',
#   u'NCSA, Research Scientist ( [http://jobs.illinois.edu/search-jobs/job-details?jobID=38241 ad] )',
#   u'due January 31, 2014.'],
#  [u'Swinburne Centre for Astrophysics & Supercomputing, Directior',
#   u'Swinburne Centre for Astrophysics & Supercomputing, Directior ( [https://jobregister.aas.org/node/44941 ad] )',
#   u'*Karl Glazebrook* appointed Jan 2014.']]
# ----------------------------------------
# Faculty Shuffle
# ----------------------------------------
# [u'People (alphabetical)', u'Old Institution', u'New Institution']
# [[u'Kevin Huffenberger',
#   u'Kevin Huffenberger',
#   u'University of Miami',
#   u'Florida State'],
#  [u'Ray Jayawardhana',
#   u'Ray Jayawardhana',
#   u'University of Toronto',
#   u'York University (Dean of Science)'],
#  [u'Lisa Kaltenegger', u'Lisa Kaltenegger', u'MPIA', u'Cornell'],
#  [u'Davide Lazzati', u'Davide Lazzati', u'NCSU', u'Oregon State'],
#  [u'Rosalba Perna',
#   u'Rosalba Perna',
#   u'University of Colorado - Boulder',
#   u'SUNY - Stony Brook'],
#  [u'Kevin Pimbblet',
#   u'Kevin Pimbblet',
#   u'Monash (Australia)',
#   u'Hull (England)'],
#  [u'Sarah Dodson-Robinson',
#   u'Sarah Dodson-Robinson',
#   u'University of Texas-Austin',
#   u'University of Delaware'],
#  [u'Dale Kocevski',
#   u'Dale Kocevski',
#   u'University of Kentucky',
#   u'Colby College'],
#  [u'Rob Fender',
#   u'Rob Fender',
#   u'University of Southampton',
#   u'University of Oxford'],
#  [u'Marc Seigar',
#   u'Marc Seigar',
#   u'University of Arkansas Little Rock',
#   u'University of Minnesota Duluth (Head of Physics)'],
#  [u'Steve Drasco',
#   u'Steve Drasco',
#   u'Grinnell College',
#   u'Cal Poly, San Luis Obispo'],
#  [u'Charlie Conroy', u'Charlie Conroy', u'UCSC', u'Harvard'],
#  [u'Laura Cadonati', u'Laura Cadonati', u'UMass - Amherst', u'Georgia Tech'],
#  [u'Bryan Gaensler',
#   u'Bryan Gaensler',
#   u'University of Sydney',
#   u'Dunlap Institute (Director), Univ. of Toronto'],
#  [u'Maria Lugaro',
#   u'Maria Lugaro',
#   u'Monash University',
#   u'Budapest (Momentum Fellowship)'],
#  [u'Shelley Wright',
#   u'Shelley Wright',
#   u'University of Toronto',
#   u'UC San Diego'],
#  [u'Dante Minitti',
#   u'Dante Minitti',
#   u'PUC Chile',
#   u'Universidad Andres Bello']]

# %%
print data[-1]['version']
print BeautifulSoup(data[-1]['preview']).find('table').find_all('td')[3].prettify()
# ['\n'.join(x['changes']) for x in data[1:]]
# Out:
# 653
# <td class="wikicell" width="434">
#  <strong>
#   Matthew Pieri
#  </strong>
# </td>
