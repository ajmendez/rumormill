# %%
import json
from pprint import pprint
from dateutil import parser
from bs4 import BeautifulSoup
from pysurvey.plot import setup, line, legend, box, dateticks
from matplotlib.dates import date2num

# %%
# data = json.load(open('faculty_2014.json'))
data = json.load(open('mill_2014.json'))

# %%
len(data), type(data), np.array(data[0].keys())
# Out:
# (32,
#  list,
#  array([u'comment', u'version', u'oldver', u'newver', u'user', u'date',
#        u'preview', u'changes'],
#       dtype='<U7'))

# %%
np.array([x.get('newver', 0) for x in data])
# Out:
# array([1139, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149,
#        1150, 1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160,
#        1161, 1162, 1163, 1164, 1165, 1167, 1168, 1169, 1170, 1171])

# %%
dates = np.array([parser.parse(x['date']) for x in data])
changes = np.array([len(x['comment']) for x in data])
changes = np.array([len(x['changes']) for x in data])

# %%
setup(figsize=(12,12))
plot(date2num(dates),changes, 's')
dateticks()

# %%
def parse_preview_table(s):
    header = []
    rows = []
    for i, tr in enumerate(s.find_all('tr')):
        if i == 0:
            # it is not clear if i need this since 
            # they are special th values
            for th in tr.find_all('th'):
                header.append(th.text.strip())
        else:
            tmp = []
            
            # populate the links
            for a in tr.find_all('a'):
                a.insert_after('[{} {}]'.format(a['href'], a.text.strip())
                                        .replace('a ] d','ad]'))
                a.extract()
            
            # populate the bolded people
            for strong in tr.find_all('strong'):
                strong.insert_after(u'*{}*'.format(strong.text.strip()))
                strong.extract()
            
            # Get the columns of the row
            tmp.extend([' '.join(td.text.strip()
                                   .replace('(          )','')
                                   .split())
                        for td in tr.find_all('td')])
            
            # create a simple tag for the intro
            tmp.insert(0,tmp[0].split('(')[0].strip())
            
            rows.append(tmp)
    return header, rows

def get_title(soup):
    try:
        # crawl up the tree ten times.
        for i in range(10):
            s = soup.previous_element.strip()
            if len(s) > 0:
                return s
            else:
                soup = soup.previous_element
    except Exception as e:
        print e
        return 'No Title found'
    
    
def parse_preview_faculty(soup):
    for s in soup.find_all('table',{'class':'wikitable'}):
        print '-'*40
        print get_title(s)
        print '-'*40
        header, rows = parse_preview_table(s)
        print header
        pprint(rows[:])

#         print header
#         break
#     print soup.prettify()

soup = BeautifulSoup(data[-1]['preview'])
parse_preview_faculty(soup)
# Out:
# ----------------------------------------
# Postdoc or term positions
# ----------------------------------------
# [u'Place/Institution (alphabetical)', u'People (in boldface if accepted)']
# [[u'Academia Sinica',
#   u'Academia Sinica (Taiwan, [http://jobregister.aas.org/job_view?JobID=45797 ad] )',
#   u'Offered to Rubab Khan (declined), Radek Wojtak, Cristian Eduard Rusu (declined)'],
#  [u'AIP Potsdam Schwarzschild Fellowship',
#   u'AIP Potsdam Schwarzschild Fellowship (extragalactic only, [http://jobregister.aas.org/node/46303 ad] )',
#   u'due Dec. 15, 2013. Offer made to *Else Starkenburg*'],
#  [u'AIP Potsdam PEPSI/LBT post-docs',
#   u'AIP Potsdam PEPSI/LBT post-docs',
#   u'offer to Claude (Trey) Mack'],
#  [u'AMNH Fellowship',
#   u'AMNH Fellowship ( [http://jobregister.aas.org/job_view?JobID=45298 ad] )',
#   u'due Oct 25, 2013. 128 expressions of interest received. 2 picked. Rejections sent.'],
#  [u'Argonne National Laboratory post-docs in physical cosmology',
#   u'Argonne National Laboratory post-docs in physical cosmology ( [http://inspirehep.net/record/1251653 ad] ); regular post-docs, up to two positions available ( [http://inspirehep.net/record/1255758 ad] )',
#   u'Shortlist notified. LSS/CMB offer made to *Samuel Flender.* LSS/surveys ** offer made to *Vinu Vikram* .'],
#  [u'University of Alabama in Huntsville',
#   u'University of Alabama in Huntsville ( [http://jobregister.aas.org/node/45524 ad] )',
#   u'due Dec. 1, 2013'],
#  [u'Univeristy of Arizona, Theory Fellowship',
#   u'Univeristy of Arizona, Theory Fellowship ( [http://jobregister.aas.org/job_view?JobID=45832 ad] )',
#   u'Some requests for phone interviews made, including James Owen and Eric Lopez. Some rejections sent. Offer made and accepted.'],
#  [u'Univeristy of Arizona',
#   u'Univeristy of Arizona (/w Rieke, [http://jobregister.aas.org/job_view?JobID=45997 ad] )',
#   u'offers made to *Lisa May Walker* , Christina Williams'],
#  [u'Univeristy of Arizona',
#   u'Univeristy of Arizona (/w Smith, [http://jobregister.aas.org/job_view?JobID=46457 ad] )',
#   u'due Dec. 31, 2013'],
#  [u'Univeristy of Arizona',
#   u'Univeristy of Arizona (/w Matheson and Saha, [http://jobregister.aas.org/job_view?JobID=46474 ad] )',
#   u'due Dec. 31, 2013'],
#  [u'Arizona State', u'Arizona State (theoretical cosmology)', u'due Jan 20th'],
#  [u'Arizona State SESE Exploration Fellowship',
#   u'Arizona State SESE Exploration Fellowship ( [http://jobregister.aas.org/node/46113 ad] )',
#   u'offer made to Jenna Kloosterman (declined)'],
#  [u'ASTRON Fellowhips',
#   u'ASTRON Fellowhips',
#   u'Shortlist notified. Interviews underway. Some rejections sent. Offer made to *Kelley Hess (joint with Kapteyn/Groningen)*'],
#  [u'ASTRON, RadioLife',
#   u'ASTRON, RadioLife (w/ Morganti, [http://jobregister.aas.org/job_view?JobID=46305 ad] )',
#   u'Offer made to *Jeremy Harwood*'],
#  [u'Banting Postdoctoral Fellowship',
#   u'Banting Postdoctoral Fellowship ( [http://banting.fellowships-bourses.gc.ca/home-accueil-eng.html ad] )',
#   u'Offers to be made by March 31, 2014'],
#  [u'University of Bern, Center for Space and Habitability',
#   u'University of Bern, Center for Space and Habitability (with Alibert and Heng) ( [http://jobregister.aas.org/job_view?JobID=46087 ad] )',
#   u'Shortlist: Daniel Kitzmann, Sourav Chatterjee.'],
#  [u'Berkeley BCCP CDS',
#   u'Berkeley BCCP CDS ( [http://jobregister.aas.org/job_view?JobID=45181 ad] )',
#   u'two offers made and accepted.'],
#  [u'Berkeley BCCP Fellowship',
#   u'Berkeley BCCP Fellowship ( [https://aprecruit.berkeley.edu/apply/JPF00247 ad] )',
#   u'Due Dec. 3, 2013. Any news?'],
#  [u'Berkeley Miller Fellowship',
#   u'Berkeley Miller Fellowship ( [http://millerinstitute.berkeley.edu/page.php?nav=11 ad] )',
#   u'offered to Blakesley Burkhart (declined) , *Tijmen de Haan, Ryan Trainor*'],
#  [u'Berkeley TAC Fellowship',
#   u'Berkeley TAC Fellowship',
#   u'short list includes Daniel Tamayo, Jill Naiman, James Owen, Girish Kulkarni, Mark Richardson, Paul Torrey, Colin Hill, Nick Battaglia; offered to *Paul Duffell* , *Mikhail Belyaev* , Cora Dvorkin (declined), *Marcel van Daalen* .'],
#  [u'Berkeley TCAN Star Formation',
#   u'Berkeley TCAN Star Formation (with McKee and Klein, [https://aprecruit.berkeley.edu/apply/JPF00248 ad] )',
#   u'Offer made to Kengo Tomida (declined).'],
#  [u'University of Bonn',
#   u'University of Bonn (with Porciani) ( [https://jobregister.aas.org/job_view?JobID=47306 ad] )',
#   u'Shortlist made. Some interviews being scheduled.'],
#  [u'Boston University',
#   u'Boston University (low mass stars w/ A. West) ( [http://jobregister.aas.org/node/46185 ad] )',
#   u'shortlist made. some interviews at AAS.'],
#  [u'Caltech',
#   u'Caltech (with Martin) ( [http://jobregister.aas.org/node/46952 a] d)',
#   u'due Dec 30; Any news ?'],
#  [u'Caltech',
#   u'Caltech (with Dor\xe9) ( [http://jobregister.aas.org/node/46168 a] d)',
#   u'*Hao-Yi Wu*'],
#  [u'Caltech KISS Fellowship',
#   u'Caltech KISS Fellowship ( [http://kiss.caltech.edu/postdoc2013/index.html ad] )',
#   u'offered to Elisa Chisari (declined).'],
#  [u'Caltech/NexSci',
#   u'Caltech/NexSci (exoplanets w/ Ciardi) ( [http://jobregister.aas.org/node/45781 ad] )',
#   u'at least some letters requested.'],
#  [u'Caltech Planetary Astronomy Fellowship',
#   u'Caltech Planetary Astronomy Fellowship ( [http://www.gps.caltech.edu/employment/PostDoc_JCPA ad] )',
#   u'*Kat Deck*'],
#  [u'Caltech Prize Fellowships',
#   u'Caltech Prize Fellowships ( [http://jobregister.aas.org/job_view?JobID=45554 ad] )',
#   u'offered to Blakesley Burkhart (declined). Experimental Prize offered to *Erika Hamden* . Moore Fellowship offered to *Chris Hayward* .'],
#  [u'Carnegie Mellon University, McWilliams Fellowship',
#   u'Carnegie Mellon University, McWilliams Fellowship ( [https://academicjobsonline.org/ajo/jobs/2963 ad] )',
#   u'Offered to *Simeon Bird* , Elisa Chisari (declined), *Anthony* *Pullen* (Feb 14)'],
#  [u'Carnegie Mellon University Postdoctoral postitions',
#   u'Carnegie Mellon University Postdoctoral postitions (in Cosmology/ML/Stat) ( [https://academicjobsonline.org/ajo/jobs/3206 ad)]',
#   u"due Dec. 15, 2013. Shortlist includes Raffaele D'Abrusco."],
#  [u'Carnegie Fellowship',
#   u'Carnegie Fellowship ( [http://jobregister.aas.org/job_view?JobID=45382 ad] )',
#   u'due Dec. 15, 2013; shortlist made and interviews at the AAS meeting are being scheduled, including Ben Shappee, Jennifer van Saders, Rubab Khan, Brett Andrews, Rachael Beaton, Michelle Collins, Jabran Zahid, Dan Milisavljevic, Anna Nierenberg. Offer made and accepted. *Jennifer van Saders, Ben Shappee* .'],
#  [u'Carnegie Observatories',
#   u'Carnegie Observatories (/w Freedman, [http://jobregister.aas.org/job_view?JobID=46755 ad] )',
#   u'due Jan. 15, 2014. Offered to *Rachael Beaton*'],
#  [u'Carnegie Observatories',
#   u'Carnegie Observatories (/w Kollmeier, [http://jobregister.aas.org/job_view?JobID=46758 ad] )',
#   u'Offer made and accepted'],
#  [u'Carnegie-Princeton Fellowship',
#   u'Carnegie-Princeton Fellowship ( [http://jobregister.aas.org/job_view?JobID=45460 ad] )',
#   u'due Dec. 13, 2013. Offered to *Jennifer van Saders, Ben Shappee* .'],
#  [u'Carnegie Institution of Science - Alvin E. Nashman Postdoctoral Fellowship',
#   u'Carnegie Institution of Science - Alvin E. Nashman Postdoctoral Fellowship',
#   u"Shortlist includes Marcel van Daalen, Mark Richardson, Chervin Laporte, Stephanie Tonnesen, Anson D'Aloisio, Blakesley Burkhart (withdrawn), Amanda Ford. Offer made to Stephanie Tonnesen."],
#  [u'Carnegie Origins Fellowship',
#   u'Carnegie Origins Fellowship (Pasadena and DC) ( [http://jobregister.aas.org/node/45372 ad] )',
#   u'due Nov. 15, 2013; shortlist made. Some interviews at AAS, including Eric Lopez, Johanna Teske. Offer made Jan 22, declined Jan 30. Second offer made Feb 7 and *accepted (Johanna Teske)* .'],
#  [u'Carnegie DTM Fellowship, Astronomy and Planetary Science',
#   u'Carnegie DTM Fellowship, Astronomy and Planetary Science ( [http://jobregister.aas.org/node/45366 ad] )',
#   u'due Dec. 1, 2013. Offer made to *Nathan Kaib* .'],
#  [u'Carnegie DTM', u'Carnegie DTM (w/ Weinberger)', u'*Jessica Donaldson*'],
#  [u'CAASTRO/AAO postdoc with Croom & Couch',
#   u'CAASTRO/AAO postdoc with Croom & Couch ( [http://jobregister.aas.org/node/46351 ad] )',
#   u'reference letters requested. Shortlist made and some interviews scheduled.'],
#  [u'CAASTRO at Australia institutes, 11 positions',
#   u'CAASTRO at Australia institutes, 11 positions ( [http://caastro.org/jobs ad] )',
#   u'Offers made to *(Emil Lenc ->?)* , Johan Samsing. Some rejections sent.'],
#  [u'CATO-Soar Fellowship',
#   u'CATO-Soar Fellowship ( [http://jobregister.aas.org/job_view?JobID=45771 ad] )',
#   u'due Dec. 1, 2013. Offer made.'],
#  [u'CEA-Saclay with Arnaud',
#   u'CEA-Saclay with Arnaud ( [http://jobregister.aas.org/node/45825 ad] )',
#   u'Short list made and interviews completed. Shortlist includes Tim Weinzirl.'],
#  [u"CEA-Saclay with Le Floc'h",
#   u"CEA-Saclay with Le Floc'h ( [http://jobregister.aas.org/node/46206 ad] )",
#   u'due Dec. 20, 2013. Any news? (02/18: Shortlist Made)'],
#  [u'CEA-Saclay with Starck',
#   u'CEA-Saclay with Starck ( [http://www.euclid-ec.org/?page_id=3047 ad] )',
#   u'due Jan. 31, 2014. Short list made, including Stefano Camera. Offer made to Stefano Camera.'],
#  [u'CEA-Saclay with Y\xe8che',
#   u'CEA-Saclay with Y\xe8che (eBOSS; [http://jobregister.aas.org/job_view?JobID=47427 ad] )',
#   u"shortlist includes Jennifer Piscionere, Raffaele D'Abrusco"],
#  [u'CEFCA',
#   u'CEFCA (J-PAS; [http://jobregister.aas.org/job_view?JobID=46804 ad] )',
#   u'Short list includes Jennifer Piscionere'],
#  [u'Centre for Extragalactic Theory Fellowship - UWC/SAAO/AIMS, Cape Town',
#   u'Centre for Extragalactic Theory Fellowship - UWC/SAAO/AIMS, Cape Town ( [https://jobregister.aas.org/node/45930 ad] )',
#   u'*Vimal Simha*'],
#  [u'Centre for Planetary Sciences Fellowship - University of Toronto at Scarborough',
#   u'Centre for Planetary Sciences Fellowship - University of Toronto at Scarborough ( [http://jobregister.aas.org/node/45713 ad] )',
#   u'Offers made to *Daniel Tamayo* and *Amaury Triaud* . All offers have been made.'],
#  [u'Chalmers University w. Wouter Vlemmings',
#   u'Chalmers University w. Wouter Vlemmings (2 positions, Evolved Stars & Star Formation, [http://jobregister.aas.org/job_view?JobID=46734 ad] )',
#   u'due Jan. 15, 2014.'],
#  [u'China-Chile Joint Center for Astronomy',
#   u'China-Chile Joint Center for Astronomy (CCJCA) Fellowship ( [http://jobregister.aas.org/job_view?JobID=45272 ad] )',
#   u'due Aug. 31, 2013. Offer made to Evelyn Johnston (declined).'],
#  [u'CITA Postdoctoral Fellowships',
#   u'CITA Postdoctoral Fellowships',
#   u'Offers made to Colin Hill (declined), Daan Meerburg, Yacine Ali-Ha\xefmoud (declined), Sijing Shen, Alex van Engelen, *Christa Van Laerhoven*'],
#  [u'CITA National PDF @ McMaster',
#   u'CITA National PDF @ McMaster',
#   u'Offer made to Mark Richardson (declined).'],
#  [u'CITA Senior Research Associates', u'CITA Senior Research Associates', ''],
#  [u'Columbia Science Fellowship',
#   u'Columbia Science Fellowship ( [http://academicjobs.columbia.edu/applicants/jsp/shared/frameset/Frameset.jsp?time=1387476728585 ad] )',
#   u'due Jan. 15, 2014.'],
#  [u'CNRS/CPPM',
#   u'CNRS/CPPM (SDSS/BOSS; [http://jobregister.aas.org/job_view?JobID=47701 ad] )',
#   u'shortlist includes Jennifer Piscionere'],
#  [u'CSIRO Astronomy & Space Science, Australia Telescope National Facility',
#   u'CSIRO Astronomy & Space Science, Australia Telescope National Facility ( [http://jobregister.aas.org/node/45644 ad] )',
#   u'*Jing Wang*'],
#  [u'JILA, University of Colorado Boulder',
#   u'JILA, University of Colorado Boulder (astrophysics theory group) ( [http://jobregister.aas.org/job_view?JobID=46191 ad] )',
#   u"*Ryan O'Leary*"],
#  [u'DAMTP, University of Cambridge',
#   u'DAMTP, University of Cambridge (3 positions in accretion discs, exoplanetary systems, and Solar MHD) ( [http://www.jobs.cam.ac.uk/job/2691/ ad] )',
#   u'due Jan. 31, 2014.'],
#  [u'DARK Fellowships',
#   u'DARK Fellowships (Copenhagen) ( [http://jobregister.aas.org/node/46008 ad] )',
#   u'due Dec. 1, 2013; over 200 applications; shortlist includes Arianna Di Cintio, Shunsaku Horiuchi, Aycin Aykutalp, Tullia Sbarrato, Daniel Perley; offers made, including *Arianna Di Cintio* , Shunsaku Horiuchi, *Daniel Perley*'],
#  [u'DESY theoreticle astroparticle postdoc',
#   u'DESY theoreticle astroparticle postdoc (Zeuthen)( [http://inspirehep.net/record/1266852 ad] )',
#   u'Offer made to *Shan Gao*'],
#  [u'Dunlap Fellowship',
#   u'Dunlap Fellowship (UToronto)',
#   u'due Jan. 6, 2014. Offers made including *John Antoniadis* . Rejections sent.'],
#  [u'Durham University',
#   u'Durham University ( [http://jobregister.aas.org/node/46373 ad] )',
#   u'due Jan. 5, 2014. Shortlist includes Daniel Angles-Alcazar, Jan-Pieter Paardekooper, Federico Marinacci. Offered to Sijing Shen, Daniel Angles-Alcazar, *Nuala McCullagh* . 3/13: Any news?'],
#  [u'ESA Fellowships',
#   u'ESA Fellowships ( [http://jobregister.aas.org/job_view?JobID=45223 ad] )',
#   u'Interviews on Nov. 27-28 (Madrid) and Dec. 2-4 (Noordwijk). Shortlist made, some rejection letters sent. Shortlist includes Janine Pforr. Offers made, including Timothy A. Davis (Declined), Nathalie Degenaar, Anne Lohfink (declined), Dominika Wylezalek (declined) , rejections sent'],
#  [u'ESO fellowships Garching',
#   u'ESO fellowships Garching ( [http://www.eso.org/sci/activities/FeSt-overview/ESOfellowship.html ad] )',
#   u'Phone interviews are being scheduled (for 28 Nov - 6 Dec). Short list includes Rubab Khan. Some rejections sent. Offers made, including Jayne Birkby (declined), Matteo Brogi (declined), Michelle Collins (declined), *Melissa McClure* , Else Starkenburg (declined), John Tobin (declined), *Ruud Visser* .'],
#  [u'ESO fellowships Chile',
#   u'ESO fellowships Chile ( [http://www.eso.org/sci/activities/FeSt-overview/ESOfellowship.html ad] )',
#   u'Phone interviews are being scheduled (for 16-19 Dec). Short list includes Jessica Donaldson, Johanna Teske. Rejections sent. Offers made, including *Linda Watson* , ** Johanna Teske (declined), *Evelyn Johnston.*'],
#  [u'Einstein Fellowship',
#   u'Einstein Fellowship ( [http://cxc.harvard.edu/fellows/fellowsCfP.html ad] )',
#   u'Offers made to: *Sagi Ben-Ami (SAO)* , *Blakesley Burkhart ( Harvard + ITC/SMA* *)* , Cora Dvorkin (declined), *Justin Ellis (JPL)* , *Wen-fai Fong (Arizona)* , *Francois Foucart (LBNL)* , *Kazumi Kashiyama ( UC Berkeley* *)* , *Ashley King (Stanford + Kavli fellow)* , *Ji-hoon Kim (Caltech)* , Georgiana Ogrean (declined), *Alexander Sadowski (MIT)* , *Johan Samsing (Princeton + Spitzer Fellow)* , *Grant Tremblay (Yale)* , *Karen Hsiang-Yi Yang (Maryland)* .'],
#  [u'ETH Zwicky Prize Fellowships',
#   u'ETH Zwicky Prize Fellowships ( [http://jobregister.aas.org/node/45935 ad] )',
#   u'due Dec. 6, 2013. Rejections sent. Shortlist includes Daniel Angles-Alcazar, Nishant Agarwal.'],
#  [u'ETH Zurich',
#   u'ETH Zurich (star clusters w/Meyer, [http://jobregister.aas.org/job_view?JobID=46398 ad] )',
#   u'offer made and *accepted*'],
#  [u'ETH postdoc',
#   u'ETH postdoc ( [http://jobregister.aas.org/node/46366 ad] )',
#   u'offer made to Tomasz Kacprzak.'],
#  [u'EPFL 2 postdocs',
#   u'EPFL 2 postdocs ( [http://jobregister.aas.org/job_view?JobID=45743 ad] )',
#   u'offer made to Tomasz Kacprzak.'],
#  [u'Event Horizon Telescope Fellowship',
#   u'Event Horizon Telescope Fellowship (CfA/SAO, [http://jobregister.aas.org/job_view?JobID=46248 ad] )',
#   u'Shortlist includes Guilin Liu (withdrawn).'],
#  [u'Excellence Cluster Universe Fellowship',
#   u'Excellence Cluster Universe Fellowship (Garching) [http://jobregister.aas.org/node/45309 (ad)]',
#   u'Offer made to Michelle Collins (declined), Aurelien Benoit-Levy (declined), *Assaf Sternberg* .'],
#  [u'University of Exeter',
#   u'University of Exeter (w/ Bate, [http://jobregister.aas.org/node/46941 ad] )',
#   u'due Jan. 15, 2014'],
#  [u'University of Exeter',
#   u'University of Exeter (w/ Dobbs, [http://jobregister.aas.org/node/47301 ad] )',
#   u'due Jan. 31, 2014'],
#  [u'University of Exeter',
#   u'University of Exeter (w/ Sing, [http://jobregister.aas.org/job_view?JobID=45830 ad] )',
#   u'due Nov. 30, 2013. Some rejections sent.'],
#  [u'University of Exeter',
#   u'University of Exeter (w/ Kraus, [http://jobregister.aas.org/job_view?JobID=47457 ad] )',
#   u'due Feb. 28, 2014'],
#  [u'Five College Astronomy Dept. Research and Teaching Fellow',
#   u'Five College Astronomy Dept. Research and Teaching Fellow (@Smith College, Observational astronomy) ( [http://www.smith.edu/astronomy/fellow.php ad] )',
#   u'Longlist made (unofficial notifications sent Jan. 6), including David Syphers, Natalie Gosnell, Allyson Sheffield, Tyler Desjardins, Benjamin Sargent, Rachael Beaton. Longlist was not interviewed, but an offer was nonetheless made and accepted ( *Anne Jaskot* ).'],
#  [u'Florida State University, 3 positions in SNe, star formation, and cosmology [http://jobregister.aas.org/job_view?JobID=45779',
#   u'Florida State University, 3 positions in SNe, star formation, and cosmology [http://jobregister.aas.org/job_view?JobID=45779 (ad)]',
#   u'due Dec. 16, 2013. Offer made to Bo Zhao'],
#  [u'Fermilab David N. Schramm Fellow in Theoretical Astrophysics and Theoretical Astrophysics Fellow',
#   u'Fermilab David N. Schramm Fellow in Theoretical Astrophysics and Theoretical Astrophysics Fellow ( [http://academicjobsonline.org/ajo/jobs/3353 ad] )',
#   u'*Sean Tulin*'],
#  [u'Franklin & Marshall',
#   u'Franklin & Marshall (2yr Vist. Asst. Prof; [http://jobregister.aas.org/node/47353 ad] )',
#   u'87 applications'],
#  [u'Gliese Fellowship, U. Heidelberg',
#   u'Gliese Fellowship, U. Heidelberg ( [http://jobregister.aas.org/job_view?JobID=46256 ad] )',
#   u'January 2014: 130 applications. Rejection letters sent. Offers made to Facundo Gomez (declined), Nick Indriolo (declined), Melissa McClure (declined), Else Starkenburg (declined), Ruud Visser (declined), and at least one more (declined)'],
#  [u'Gemini Fellowship',
#   u'Gemini Fellowship ( [http://jobregister.aas.org/job_view?JobID=46080 ad] )',
#   u'due Dec. 1, 2013. Interviews underway, including Guilin Liu, Johanna Teske. Offered to Johanna Teske (declined). Offered to *Hsin-Yi Shih* (Gemini North).'],
#  [u'Georgia Tech',
#   u'Georgia Tech (Theoretical and Computational Astrophysics Network; massive black hole formation and fueling) ( [http://jobregister.aas.org/job_view?JobID=45690 ad] )',
#   u'Two offers made and *accepted* . One offer made to Takamitsu Tanaka (declined).'],
#  [u'Georgia State University',
#   u'Georgia State University (w/ Bentz)',
#   u'Offer made (1/28; declined). Offer made to Tyler Desjardins (2/18; declined).'],
#  [u'GRAPPA Postdoctoral Fellowship',
#   u'GRAPPA Postdoctoral Fellowship ( [http://jobregister.aas.org/job_view?JobID=45925 ad] )',
#   u'due Dec. 1.'],
#  [u'Harvard University Advanced Studies of Exoplanet Atmospheres with Charbonneau',
#   u'Harvard University Advanced Studies of Exoplanet Atmospheres with Charbonneau',
#   u'Offer made to Jayne Birkby.'],
#  [u'Harvard University GRBs and Time domain Astrophysics with Berger',
#   u'Harvard University GRBs and Time domain Astrophysics with Berger',
#   u'due Jan. 15, 2014. Offer made to Curtis McCully.'],
#  [u'Harvard-Smithsonian CfA - Clay Fellowship',
#   u'Harvard-Smithsonian CfA - Clay Fellowship ( [http://www.cfa.harvard.edu/opportunities/fellowships/clay/ ad] )',
#   u'More than 200 applications. Offered to Christoph Federrath (declined). Rejections sent. Offer made to *Jabran Zahid* .'],
#  [u"Harvard's Institute for Theory and Computation",
#   u"Harvard's Institute for Theory and Computation (ITC) Fellowship, Harvard-Smithsonian CfA ( [http://www.cfa.harvard.edu/opportunities/fellowships/itc/ ad] )",
#   u'Shortlist notified, offers made to *Blakesley Burkhart (joint with SMA+ Einstein)* , *Cora Dvorkin (joint with Hubble)* , *Laura Lopez (joint with Hubble), Michael McCourt (ITC), Jill Naiman (joint with NSF)* . Shortlist included: Jennifer van Saders, Paul Duffell. Some rejections sent.'],
#  [u'Harvard-MIT Future Faculty Leaders Fellowship',
#   u'Harvard-MIT Future Faculty Leaders Fellowship ( [http://www.cfa.harvard.edu/opportunities/fellowships/harvard-mit/ ad] )',
#   u'due Feb. 1, 2014; shortlists created for both Harvard and MIT positions; short-listed individuals for Harvard position have been contacted and interviewed; MIT selection ongoing.'],
#  [u'Haverford College',
#   u'Haverford College (with Narayanan) ( [http://desika.haverford.edu/job-opportunities/ ad] )',
#   u'Offer made; waitlist notified.'],
#  [u'The Hebrew University of Jerusalem',
#   u'The Hebrew University of Jerusalem (with Dekel) ( [http://www.phys.huji.ac.il/post-fellow-astro.html ad] )',
#   u'Offer made to *Matteo Tomassetti* , Girish Kulkarni.'],
#  [u'Heidelberg Institute for Theoretical Studies',
#   u'Heidelberg Institute for Theoretical Studies (HITS, w/ Springel, [http://jobregister.aas.org/node/46084 ad] )',
#   u'due Dec. 15, 2013. Shortlist includes Daniel Angles-Alcazar. Offers made to Sijing Shen, Daniel Angles-Alcazar.'],
#  [u'Heidelberg University',
#   u'Heidelberg University (w/ Klessen, [http://jobregister.aas.org/node/46383 ad] )',
#   u'Shortlist includes Bhaskar Agarwal. Offers made to Girish Kulkarni, *Jan-Pieter Paardekooper* .'],
#  [u'Helsinki Institute of Physics, Postdoctoral Fellowship in cosmology',
#   u'Helsinki Institute of Physics, Postdoctoral Fellowship in cosmology ( [http://cosmocoffee.info/viewtopic.php?t=2214 ad] )',
#   u'due Dec 15, 2013.'],
#  [u'Henri Poincar\xe9 Postdoctoral fellowship',
#   u'Henri Poincar\xe9 Postdoctoral fellowship ( [http://jobregister.aas.org/node/45254 ad] )',
#   u'shortlist includes Yamila Miguel, Alexander Fritz'],
#  [u'Hubble Fellowships',
#   u'Hubble Fellowships',
#   u"*Fabienne Bastien (Penn State)* , *Matteo Brogi (CU Boulder)* , *Michelle Collins (Yale)* , *Ryan Cooke (UCSC),* Timothy A. Davis (declined), *Jason Dexter (Columbia)* , *Cora Dvorkin (Harvard + ITC fellow)* , *Shy Genel (Columbia)* , Ashley King (Declined), *Laura Lopez (Harvard)* , *Joey Neilsen (MIT)* , *Evan O'Connor (NCSU)* , *Georgiana Ogrean (SAO)* , *James Owen (IAS)* , *Amy Reines (University of Michigan + Society of Fellows)* , Matthew Schenker (declined), *Ben Shappee (Carnegie)* , *Andrew Skemer (Arizona)* , Jabran Zahid (declined), *Guangtun Zhu (JHU)* , *Sjoert van Velzen (STScI)* . Waitlist of 6-7 has been notified. 282 applications submited. Rejections sent."],
#  [u'INAF-Brera Obs, ERC "Darklight" Fellowships',
#   u'INAF-Brera Obs, ERC "Darklight" Fellowships (w Guzzo)',
#   u'Shortlist made, including Stefano Camera. Some interviews being scheduled. At least one offer made and *accepted* . *Jun Koda* .'],
#  [u'INAF/Osservatorio di Roma',
#   u'INAF/Osservatorio di Roma (with Schneider; [http://jobregister.aas.org/job_view?JobID=46704 ad] )',
#   u'Offer made to Jan-Pieter Paardekooper (declined). Offer made to *Luca Graziani* .'],
#  [u'International Centre for Radio Astronomy Research at The University of Western Australia',
#   u'International Centre for Radio Astronomy Research at The University of Western Australia (with Power; [http://external.jobs.uwa.edu.au/cw/en/job/492744/research-associate-ref-492744-computational-astrophysics ad] )',
#   u'Offer made and *accepted*'],
#  [u'International Centre for Radio Astronomy Research at The University of Western Australia',
#   u'International Centre for Radio Astronomy Research at The University of Western Australia (with Robotham; [http://external.jobs.uwa.edu.au/cw/en/job/492745/research-associate-ref-492745-observational-astrophysics ad] )',
#   u'Offer made and *accepted*'],
#  [u'International Centre for Theoretical Physics - South American Institute for Fundamental Research',
#   u'International Centre for Theoretical Physics - South American Institute for Fundamental Research (ICTP-SAIFR) and University of Sao Paulo (USP) ( [http://www.ictp-saifr.org/?page_id=625 ad] )',
#   u'due Dec 15, 2013.'],
#  [u"Institut d'Astrophysique de Paris",
#   u"Institut d'Astrophysique de Paris (Computational Gravitational Dynamics with Colombi; [http://jobregister.aas.org/node/46575 ad] )",
#   u'Offer accepted by *Ana\xeblle Hall\xe9* .'],
#  [u"Institut d'Astrophysique de Paris",
#   u"Institut d'Astrophysique de Paris (with Volonteri; [http://jobregister.aas.org/job_view?JobID=47181 ad] )",
#   u'Interviews being scheduled, including Michele Compostella.'],
#  [u'Institut Lagrange de Paris - Lagrange Fellows',
#   u'Institut Lagrange de Paris - Lagrange Fellows ( [http://jobregister.aas.org/job_view?JobID=46187 ad] )',
#   u'Offers made to *Eleonora Di Valentino* , Johan Samsing,Dan Scolnic (decline), *Eirik Svanes, Mariangela Settimo*'],
#  [u'Institute of Astronomy, Univ. of Cambridge',
#   u'Institute of Astronomy, Univ. of Cambridge ( [http://www.ast.cam.ac.uk/vacancy/2964 ad] )',
#   u'due Jan. 6, 2014., shorlist includes Jill Naiman. Offer made to *Sijing Shen* . Rejection letters sent.'],
#  [u'Instituto de Astrofisica de Canarias -',
#   u'Instituto de Astrofisica de Canarias - (Massive Stars, w/ Dav\xf3; [http://jobregister.aas.org/job_view?JobID=46035 ad] )',
#   u'Short list includes Jennifer Andrews, Joachim Michael Bestenlehner, *Melanie Godart*'],
#  [u'Instituto de Astrofisica de Canarias -',
#   u'Instituto de Astrofisica de Canarias - (High Redshift Sources; [https://jobregister.aas.org/node/48311 ad] )',
#   u'Shortlist includes Rosa Calvi, Alexander Fritz, Nathan Roche'],
#  [u'IRAP Toulouse',
#   u'IRAP Toulouse (w/ Contini and Bouche)',
#   u'Offer made and accepted.'],
#  [u'IUCAA',
#   u'IUCAA ( Vaidya-Raychaudhuri Fellowship, [http://jobregister.aas.org/job_view?JobID=45494 ad] )',
#   u'Offered to Rubab Khan (declined).'],
#  [u'IUCAA postdoctoral positions',
#   u'IUCAA postdoctoral positions ( [http://jobregister.aas.org/job_view?JobID=45496 ad] )',
#   u'Offered to Girish Kulkarni.'],
#  [u'Jansky Fellowship',
#   u'Jansky Fellowship ( [https://science.nrao.edu/opportunities/postdoctoral-programs/jansky ad] )',
#   u'Offer made to *Chat Hull (CfA, +1 year SMA),* *Sarah Burke-Spolaor (NRAO-Socorro)* , John Tobin (declined, 2/7). Some rejections sent (1/21)'],
#  [u'JAXA International Top Young Fellowship',
#   u'JAXA International Top Young Fellowship ( [http://www.isas.jaxa.jp/e/researchers/young-fellowship/appli.shtml ad] )',
#   u'Offers made to Yoshiyuki Inoue and Shiu-Hang (Herman) Lee.'],
#  [u'University of Johannesburg',
#   u'University of Johannesburg (w/ Razzaque, [https://inspirehep.net/record/1235804 ad] )',
#   u'Offer made to Rodolfo Barniol Duran.'],
#  [u'Kapteyn Astronomical Institute',
#   u'Kapteyn Astronomical Institute (PDRA with Amina Helmi [http://jobregister.aas.org/node/46279 ad] )',
#   u'Interviews over. Offer made'],
#  [u'Kavli Institute for Cosmology, University of Cambridge',
#   u'Kavli Institute for Cosmology, University of Cambridge ( [http://jobregister.aas.org/node/45823 ad] )',
#   u'due Dec. 9, 2013. Short list includes Nishant Agarwal, Takamitsu Tanaka, Daniel Jacobs.'],
#  [u'Kavli IPMU',
#   u'Kavli IPMU (Tokyo) ( [http://jobregister.aas.org/job_view?JobID=45809 ad] )',
#   u'due Dec. 1, 2013. Shortlist includes Sandra Benitez-Herrera. Offer made to and accepted by *Edmond Cheung.*'],
#  [u'Kavli IPMU-HSC Survey',
#   u'Kavli IPMU-HSC Survey (w/ Leauthaud) ( [http://jobregister.aas.org/job_view?JobID=46650 ad] )',
#   u'Offer made to *Song Huang*'],
#  [u'Kavli',
#   u'Kavli (KIPAC) / Stanford / SLAC Fellowships ( [http://jobregister.aas.org/node/45463 ad] )',
#   u'Offers made to Johan Samsing, Elisabeth Krause, Jabran Zahid (declined), Guangtun Zhu (declined), *Ashley King(+Einstein)* , Michael McCourt, *Marco Viero* , *Ranjan Laha* , *Radek Wojtak* Some rejections sent.'],
#  ['', '', ''],
#  [u'University of Kansas',
#   u'University of Kansas (w/ Rudnick)',
#   u'Offer made to *Tyler Desjardins*'],
#  [u'KASI cosmology postdoc 3y/5y',
#   u'KASI cosmology postdoc 3y/5y ( [http://cosmology.kasi.re.kr/job.html ad] )',
#   u'Offers accepted by *Cristiano Sabiu* , *Jeeseon Song* , *Yi Zheng* .'],
#  [u'University of Kentucky',
#   u'University of Kentucky (w/ Yan, [http://jobregister.aas.org/node/46082 ad] )',
#   u'Offer made to *Kai Zhang*'],
#  [u'KIAA Fellowship',
#   u'KIAA Fellowship (Beijing) ( [http://jobregister.aas.org/node/40529 ad] )',
#   u'Offer made, includes Song Huang (declined)'],
#  [u'KIAA-PKU postdoc',
#   u'KIAA-PKU postdoc (w/ Peng) ( [https://jobregister.aas.org/node/44049 https://jobregister.aas.org/node/44049] )',
#   u'Offer made to *Sungsoon Lim*'],
#  [u'KITP',
#   u'KITP ( [http://jobregister.aas.org/job_view?JobID=45358 ad] )',
#   u'Shortlist includes James Owen.'],
#  [u'Koln University',
#   u'Koln University (w/ Walch, [http://jobregister.aas.org/node/46468 ad] )',
#   u'due Dec. 20, 2013.'],
#  [u'Kyung Hee University, Korea',
#   u'Kyung Hee University, Korea ( [http://jobregister.aas.org/node/46480 ad] )',
#   u'Offers made to Rafael S. de Souza, Michael Troxel.'],
#  [u'LAM w/ Le Fevre',
#   u'LAM w/ Le Fevre',
#   u'shortlist made, interviews underway, offer made to *Janine Pforr*'],
#  [u'LAM w/ Peroux',
#   u'LAM w/ Peroux',
#   u'Interviews underway. Shortlist notified 1/31, includes David Syphers (withdrew). some rejections sent'],
#  [u'Leiden Observatory with Huub Rottgering',
#   u'Leiden Observatory with Huub Rottgering ( [http://jobregister.aas.org/job_view?JobID=45448 ad] )',
#   u'due Oct. 15, 2013. ANY NEWS?'],
#  [u'Leiden Observatory with Alessandro Patruno',
#   u'Leiden Observatory with Alessandro Patruno ( [http://www.strw.leidenuniv.nl/jobs/patruno_postdoc.php ad] )',
#   u"Shortlist includes Roman Gold, Caroline D'Angelo, Bo Zhao and Dipanjan Mukherjee. Offer made to *Caroline D'Angelo*"],
#  [u'Leiden Observatory with Schaye',
#   u'Leiden Observatory with Schaye (MUSE position, [http://jobregister.aas.org/node/45756 ad] )',
#   u'Offer made to *David Syphers* . Rejections sent.'],
#  [u'Leiden Observatory with Schaye',
#   u'Leiden Observatory with Schaye (Theory position, [http://jobregister.aas.org/node/45751 ad] )',
#   u'due Dec. 15, 2013; Shortlist includes Rahul Kannan, Mark Richardson (withdrawn), Federico Marinacci. Offer made to *Sylvia Ploeckinger*'],
#  [u'Leiden Observatory with Labbe',
#   u'Leiden Observatory with Labbe (galaxy evolution)',
#   u'Shortlist made, interviews completed, offer made'],
#  [u'Leiden Observatory',
#   u'Leiden Observatory (star and planet formation)',
#   u'Offer made to *John Tobin* .'],
#  [u'Liverpool John Moores University',
#   u'Liverpool John Moores University (w/ Davies; [http://jobregister.aas.org/job_view?JobID=47667 ad] )',
#   u'due Feb. 28, 2014'],
#  [u'Liverpool John Moores University',
#   u'Liverpool John Moores University (w/ Longmore; [http://jobregister.aas.org/job_view?JobID=47232 ad] )',
#   u'due Feb. 1, 2014.'],
#  [u'Lowell Observatory',
#   u'Lowell Observatory (Binary star formation w/ Prato; [http://jobregister.aas.org/job_view?JobID=46074 ad] )',
#   u'due Jan. 1, 2014.'],
#  [u'Lowell Observatory',
#   u'Lowell Observatory (Exoplanets, w/ Shkolnik; [http://jobregister.aas.org/job_view?JobID=46179 ad] )',
#   u'due Jan. 1, 2014.'],
#  [u"Laboratoire d'Astrophysique de Marseille- Exoplanets/CHEOPS Mission - Exoplanets/CHEOPS Mission",
#   u"Laboratoire d'Astrophysique de Marseille- Exoplanets/CHEOPS Mission - Exoplanets/CHEOPS Mission ( [http://jobregister.aas.org/job_view?JobID=46495 ad] )",
#   u'Offered to Trifon Trifonov (withdraw).'],
#  [u'Louvain @CP3',
#   u'Louvain @CP3 (w C. Ringeval)',
#   u'Offer made to Daan Meerburg (declined)'],
#  [u'Lyon University',
#   u'Lyon University (with Richard) ( [http://calends.univ-lyon1.fr/?lang=en ad] )',
#   u'2 positions, interviews scheduled, some rejections sent'],
#  [u'Lyon University',
#   u'Lyon University (w/ Guideroni)',
#   u'interviews being scheduled'],
#  [u'Lyon University', u'Lyon University (w/ Bacon)', u'some rejections sent'],
#  [u'Lyon University',
#   u'Lyon University (w/ Blaizot, [http://jobregister.aas.org/node/46284 ad] )',
#   u'Shortlist includes Michele Compostella, Y. Rosas-Guevara'],
#  [u'CIERA Postdoctoral Fellowships, Northwestern University',
#   u'CIERA Postdoctoral Fellowships, Northwestern University ( [http://ciera.northwestern.edu/Research/fellowships.php ad] )',
#   u'Shortlist being notified (Jan 20). Offers made to *Daniel Angles-Alcazar* , Kat Deck, *Fabio Antonini, Sourav Chatterjee.*'],
#  [u'Lindheimer Postdoctoral Fellowship, Northwestern University',
#   u'Lindheimer Postdoctoral Fellowship, Northwestern University ( [http://ciera.northwestern.edu/Research/fellowships.php ad] )',
#   u'Shortlist being notified (Jan 20). Offer made to Sijing Shen (declined).'],
#  [u'Postdoctoral Positions in Astronomy and Astrophysics, Northwestern University',
#   u'Postdoctoral Positions in Astronomy and Astrophysics, Northwestern University ( [http://ciera.northwestern.edu/Research/fellowships.php ad] )',
#   u'due Dec. 1, 2013; (w/ Faucher-Giguere) shortlist includes Rahul Kannan, Marcel van Daalen, Mark Richardson.'],
#  [u'Research Scientist, Ludwig-Maximilians University in Munich',
#   u'Research Scientist, Ludwig-Maximilians University in Munich (with Mohr, [http://jobregister.aas.org/job_view?JobID=45956 ad] )',
#   u'due Nov. 1, 2013. Offer made to Silvia Galli (declined). Offer made to *Veronica Strazzullo* .'],
#  [u'Postdoctoral Scientist, Max Planck Institute for Extraterrestrial Physics',
#   u'Postdoctoral Scientist, Max Planck Institute for Extraterrestrial Physics (with Mohr, [http://jobregister.aas.org/job_view?JobID=48009 ad] )',
#   u'due Apr.30, 2014. Any news ?'],
#  [u'University of KwaZulu-Natal',
#   u'University of KwaZulu-Natal ( [http://www.acru.ukzn.ac.za/jobs/ ad] )',
#   u'due Sep 15, 2013 additional postition, due Dec. 1, 2013, shortlist made, interviews scheduled.'],
#  [u'Joint Space-Science Institute Prize Postdoc',
#   u'Joint Space-Science Institute Prize Postdoc (Univ. of Maryland / GSFC; [http://jobregister.aas.org/job_view?JobID=45676 ad] )',
#   u'due Dec. 15, 2013. Shortlist includes: Rodolfo Barniol Duran, Wen-fai Fong, Raffaella Margutti, Fabio Antonini, Daniel Angles-Alcazar. Offer made to Wen-fai Fong.'],
#  [u'Johns Hopkins University',
#   u'Johns Hopkins University ( [http://www.pha.jhu.edu/~menard/links/postdoc2013/ ad] ) multiple postdoc positions in observational and/or theoretical astrophysics, cosmology and physics.',
#   u'Offers made to *Alvise Raccanelli* , *Ely Kovetz* , *Yacine Ali-Ha\xefmoud, Alexander Mendez, Dominika Wylezalek* . Shortlist includes Daan Meerburg, Christina Williams. *Five offers made and accepted, all positions filled.*'],
#  [u'Imperial JRF',
#   u'Imperial JRF ( [http://www3.imperial.ac.uk/juniorresearchfellowships ad] )',
#   u'offered to James Owen'],
#  [u'IoA / U. Cambridge',
#   u'IoA / U. Cambridge (with Becker) ( [http://jobregister.aas.org/node/47437 ad] )',
#   ''],
#  [u'IoA / U. Cambridge',
#   u'IoA / U. Cambridge (with Clarke) ( [http://www.ast.cam.ac.uk/vacancy/2897 ad] )',
#   u'due Dec. 5; rejection letters sent.'],
#  [u'IoA / U. Cambridge',
#   u'IoA / U. Cambridge (with Fabian) ( [http://jobregister.aas.org/job_view?JobID=45465 ad] )',
#   u'At least three positions available, due Oct. 11, shortlist made, offer made (11/25) *Ashley King* , *Anne Lohfink, Ranjan Vasudevan, Stephen Walker*'],
#  [u'IoA / U. Cambridge',
#   u'IoA / U. Cambridge (with Haehnelt) ( [http://jobregister.aas.org/node/47291 ad] )',
#   u'Offer made and *accepted.*'],
#  [u'Marie Curie Fellowships',
#   u'Marie Curie Fellowships ( [http://ec.europa.eu/research/mariecurieactions/ ad] )',
#   u'Some invitations for negotiations sent (IIF:11/29), including *Jennifer Siegal-Gaskins* (IIF @ GRAPPA, University of Amsterdam), *Chiara Mingarelli* (IOF), Nathalie Degenaar, Jason Dexter.'],
#  [u'Max Planck Institute for Astronomy',
#   u'Max Planck Institute for Astronomy (MPIA, /w Jones, [http://jobregister.aas.org/job_view?JobID=45343 ad] )',
#   u'Offer made and accepted.'],
#  [u'Max Planck Institute for Astronomy',
#   u'Max Planck Institute for Astronomy (MPIA, /w Maccio, [http://www.mpia.de/Public/MPIA/jobs/13-12en.pdf ad] )',
#   u'due Dec. 15, 2013; Shortlist includes Mark Richardson, Daniel Ceverino, Jan-Pieter Paardekooper. Offer made to Sijing Shen (declined). New offer made to Mark Richardson, Jan-Pieter Paardekooper (declined).'],
#  [u'Max Planck Institute for Astronomy',
#   u"Max Planck Institute for Astronomy (MPIA, 'Galaxy and Cosmology' Fellowship, [http://www.mpia.de/Public/MPIA/jobs/13-13en.pdf ad] )",
#   u'Shortlist made and interviews scheduled. Have the shortlisted candidates been notified? Offer made to Sijing Shen.'],
#  [u'Max Planck Institute for Astronomy',
#   u"Max Planck Institute for Astronomy (MPIA, 'Planet and Star Formation' Fellowship, [http://www.mpia.de/Public/MPIA/jobs/13-14en.pdf ad] )",
#   u'due Dec. 15, 2013.'],
#  [u'Max Planck Institute for Astronomy',
#   u'Max Planck Institute for Astronomy (MPIA, Python, [http://www.mpia.de/Public/MPIA/jobs/13-16en.pdf ad] )',
#   u'Shortlist includes Tim Weinzirl'],
#  [u'Max Planck Institute for Astrophysics',
#   u'Max Planck Institute for Astrophysics (MPA, Galaxy Formation, [http://jobregister.aas.org/job_view?JobID=45724 ad] )',
#   u'due Dec. 15, 2013. All offers have been made, including to *Amanda Ford* .'],
#  [u'Max Planck Institute for Astrophysics',
#   u'Max Planck Institute for Astrophysics (MPA, Fellowship, [http://jobregister.aas.org/job_view?JobID=45726 ad] )',
#   u'due Dec. 15, 2013. Committee meets Jan 27. Offers made to: *Antonela Monachesi, Facundo Gomez, Thomas Peters* . All offers have been made.'],
#  [u'Max Planck Institute for Astrophysics',
#   u'Max Planck Institute for Astrophysics (MPA, High Energy Astrophysics, [http://jobregister.aas.org/node/46506 ad] )',
#   u'due Dec. 15, 2013. Shortlist includes Jan-Pieter Paardekooper. Offers made to *Michele Compostella* , Jason Dexter.'],
#  [u'Max Planck Institute for Gravitational Physics',
#   u'Max Planck Institute for Gravitational Physics (AEI) ( [http://www.aei.mpg.de/1121114/gwjobs2014 ad] ) multiple postdoc positions in gravitational-wave astronomy',
#   u'due Jan. 10, 2014. Offers made to: *Alejandro Bohe`, Abraham Harte, Jan Steinhoff; Tanja Hinderer (@UMD), Andrea Taracchini; Ian Harry,* Prayush Kumar (declined), *Steven Privitera, Vivien Raymond,* Stephen Taylor (declined) *; Stas Babak; Alberto Sesana;* Tony Chu (declined), Francois Foucart (declined), ** *Roland Haas, Ian Hinder.*'],
#  [u'Max Planck Institute for Extraterrestrial Physics',
#   u'Max Planck Institute for Extraterrestrial Physics (MPE) - Postdoc for Euclid ( [http://jobregister.aas.org/job_view?JobID=46209 ad] )',
#   u"shortlisted candidates contacted for interviews, shortlist includes Janine Pforr, Raffaele D'Abrusco, Rafael S. de Souza. Offer made and *accepted* (2/13)"],
#  [u'Max Planck Institute for Extraterrestrial Physics',
#   u'Max Planck Institute for Extraterrestrial Physics (MPE) w/ Genzel',
#   u'Some rejections sent'],
#  [u'Max Planck Institute for Extraterrestrial Physics',
#   u'Max Planck Institute for Extraterrestrial Physics (MPE) - Postdoc in astrochemistry and star/planet formation w/ Caselli ( [http://jobregister.aas.org/node/46653 ad] )',
#   u'due Jan. 31, 2014. Offer made to Bo Zhao, *Seyit Hocuk* .'],
#  [u'McLean Fellowship', u'McLean Fellowship (UToronto)', u'any news?'],
#  [u'Michigan Society of Fellows',
#   u'Michigan Society of Fellows ( [http://societyoffellows.umich.edu ad] )',
#   u'Offer made to *Amy Reines (+Hubble)*'],
#  [u'Minerva positions in Astrobiology',
#   u'Minerva positions in Astrobiology ( [http://www.weizmann.ac.il/ExtremeLife/node/4/content ad] )',
#   u'Extended deadline; due December 15th 2013.'],
#  [u'MIT Pappalardo Fellowship',
#   u'MIT Pappalardo Fellowship ( [http://jobregister.aas.org/job_view?JobID=45325 ad] )',
#   u'Rejections sent, finalists include Paul Duffell, Jennifer van Saders, Blakesley Burkhart (withdrawn ), Jabran Zahid, offers made to Jabran Zahid (declined), Jennifer van Saders (declined). No astrophysics fellows this year.'],
#  [u'MIT',
#   u'MIT (w/ Vogelsberger)',
#   u'short list includes Rahul Kannan, Simeon Bird, Marcel van Daalen, Federico Marinacci, Mark Richardson; some candidates contacted. Offers made to *Rahul Kannan* , *Federico Marinacci* .'],
#  [u'McGill University Postdoctoral Fellowships',
#   u'McGill University Postdoctoral Fellowships ( [http://dualcore.physics.mcgill.ca/PDF/ application website] )',
#   u'Offer made to Cora Dvorkin (declined).'],
#  [u'CITA National Fellowship at McGill University',
#   u'CITA National Fellowship at McGill University ( [http://dualcore.physics.mcgill.ca/PDF/info.html application website] )',
#   u'due Nov. 1, 2013, Shortlists made (Dec. 13, 2013).'],
#  [u'MoCA / Monash',
#   u'MoCA / Monash (w/ Heger; [http://jobs.monash.edu.au/jobDetails.asp?sJobIDs=518885 ad] )',
#   u'due Jan. 31, 2014.'],
#  [u'MoCA / Monash',
#   u'MoCA / Monash (w/ Levin; [http://jobregister.aas.org/job_view?JobID=47249 ad] )',
#   u'due Jan. 31, 2014.'],
#  [u'MPIfR',
#   u'MPIfR ( [http://jobregister.aas.org/job_view?JobID=45251 ad] )',
#   u'due Sep. 1, 2013.'],
#  [u'MPIfR cosmic magnetism',
#   u'MPIfR cosmic magnetism (with Mao, [https://jobregister.aas.org/job_view?JobID=46617 ad] )',
#   u'offer made and accepted (March 10, 2014)'],
#  [u'National Astronomical Observatories, Chinese Academy of Sciences',
#   u'National Astronomical Observatories, Chinese Academy of Sciences (NAOC) & Portsmouth joint postdoctoral fellowship (3 positions) ( [http://research.icg.port.ac.uk/node/3357 ad] )',
#   u'due Jan. 10, 2014. Theoretical cosmology position: *Ying-Li Zhang* . eBOSS position: Jun Koda (declined). ManGA position: Taehyun Kim (declined), *Zheng Zheng* .'],
#  [u'National Observatory of Athens',
#   u'National Observatory of Athens (IAASARS). Up to 2-year two postdoc positions in Observational (Optical) Astrophysics ( [http://www.astro.noa.gr/POSTDOC_ARISTEIAII.pdf application website] )',
#   u'due Dec. 10, 2013, until positions are filled. *Offers made, one accepted (starting date 1.2.2014), for the second final response is due 31.1.14.*'],
#  [u'National Observatory of Athens',
#   u'National Observatory of Athens (IAASARS). 2-year postdoc position in infrared extragalactic astrophysics ( [http://www.astro.noa.gr/POSTDOC_KRIPIS_Xilouris.pdf application website] )',
#   u'due Nov. 15, 2013, until position is filled. Some rejections sent.'],
#  [u'National Observatory of Athens',
#   u'National Observatory of Athens (IAASARS). 2-year postdoc position in astrophysics & instrumentation ( [http://www.astro.noa.gr/Boumis_postdoc.pdf application website] )',
#   u'due Nov. 10, 2013, until position is filled. Applications review begun Nov 15, 2013. *Offer made and accepted (started 1.1.2014).* Rejections sent.'],
#  [u'National Observatory of Athens',
#   u'National Observatory of Athens (IAASARS). One software engineer position and One telescope engineer position ( [http://www.astro.noa.gr/en/jobopenings/documents/engineer_proteas2.pdf ad] )',
#   u'due Apr. 25 2014'],
#  [u'National Observatory of Athens',
#   u'National Observatory of Athens (IAASARS). Marie-Curie fellowship ( [http://www.astro.noa.gr/en/jobopenings/documents/marie_curie_iaasars.pdf ad] )',
#   u'due Sep. 1, 2014'],
#  [u'National observatory of Athens',
#   u'National observatory of Athens (IAASARS) X-ray/IR Astronomy postdoctoral position ( [http://xraygroup.astro.noa.gr/vacancies.htm ad] )',
#   u'Deadline 20th August, 2014'],
#  [u"Nice, Observatoire de la C\xf4te d'Azur - Poincar\xe9 Fellowship",
#   u"Nice, Observatoire de la C\xf4te d'Azur - Poincar\xe9 Fellowship ( [http://jobregister.aas.org/job_view?JobID=45254 ad] )",
#   u'due Nov. 15, 2013. shortlist includes *Yamila Miguel* , Alexander Fritz'],
#  [u'Notre Dame',
#   u'Notre Dame (w/ Crepp)',
#   u'Offer made to *Jonathan Crass* .'],
#  [u'NORDITA Fellowships',
#   u'NORDITA Fellowships ( [http://jobregister.aas.org/job_view?JobID=45531 ad] )',
#   u'due Nov. 15, 2013. Any news?'],
#  [u'NPP',
#   u'NPP (Nasa Postdoc Program). Position in astrophysics, cosmology at various NASA institution including JPL, Goddard, etc. ( [http://nasa.orau.org/postdoc/ ad] )',
#   u'Offers made to Johanna Teske (Ames; declined), *Rubab Khan (Goddard)* , *Joleen Carlberg (Goddard),* Ofer Cohen (Goddard, declined), *Alexander Young (Goddard)* , John Tobin (Goddard, declined), *Dom Walton (JPL)* , *Johan Lindberg (Goddard), Stephen Taylor (JPL)* , *Jenna Kloosterman (JPL)* . Does anyone know how many offers? Is there a waitlist?'],
#  [u'NRAO - NAASC fellowship',
#   u'NRAO - NAASC fellowship ( [http://jobregister.aas.org/job_view?JobID=45377 ad] )',
#   u'Shortlist being notified (Jan 7). offer made to *Amanda Kepley.*'],
#  [u'NRC Herzberg Institute for Astrophysics',
#   u'NRC Herzberg Institute for Astrophysics (DAO, Victoria) - Research Fellowship ( [http://jobregister.aas.org/job_view?JobID=47313 ad] )',
#   u'Phone interviews being held. Short list includes Joel Roediger.'],
#  [u'NSF Astronomy & Astrophysics Postdoctoral Fellowship',
#   u'NSF Astronomy & Astrophysics Postdoctoral Fellowship (AAPF) ( [http://www.nsf.gov/funding/pgm_summ.jsp?pims_id=5291 ad] )',
#   u'Offers made to: Amy Reines (declined), *Serge Dieterich (Carnegie DTM)* , *Jill Naiman (joint with ITC)* , *Erika Hamden (Caltech)* , *Daniel Jacobs (ASU)* , *Aomawa Shields (Harvard/UCLA)* , *Devin Silvia (Michigan State)* . Some rejection letters sent, Waitlist notifications sent. Feb 18- Rejection letters sent to (some?) wait-listed applicants. 94 applications, 9 fellowships.'],
#  [u'Niels Bohr International Academy - 3yr postdoc',
#   u'Niels Bohr International Academy - 3yr postdoc ( [https://academicjobsonline.org/ajo/jobs/3061 ad] )',
#   u'due Dec. 1, 2013; shortlist includes Jill Naiman. Any news?'],
#  [u'Niels Bohr International Academy - 5yr assist. prof.',
#   u'Niels Bohr International Academy - 5yr assist. prof. ( [https://academicjobsonline.org/ajo/jobs/3062 ad] )',
#   u'due Jan. 15, 2014.'],
#  ['', '', ''],
#  [u'NOVA fellowships',
#   u'NOVA fellowships ( [http://jobregister.aas.org/node/45950 ad] )',
#   u'some shortlisted candidates notified. Offer made to Sijing Shen (declined), Else Starkenburg (declined).'],
#  [u'Osaka University',
#   u'Osaka University (Two positions in Theoretical Computational Astrophysics, w/ Nagamine & Shlosman) ( [http://jobregister.aas.org/job_view?JobID=47871 new ad] )',
#   u'Offer made to Y Rosas-Guevara (declined), Bo Zhao (declined), *Long Do Cao, Luo Yang.*'],
#  [u'Oskar Klein Fellowships - Stockholm U.',
#   u'Oskar Klein Fellowships - Stockholm U.',
#   u'Offer made to Johan Samsing.'],
#  [u'Ohio State CCAPP Fellowships',
#   u'Ohio State CCAPP Fellowships ( [http://ccapp.osu.edu/jobs.html ad] )',
#   u'applications reviewed beginning 15 Nov. 2013. Any news? Shortlist includes Johan Samsing, Karen Hsiang-Yi Yang. Offer to *Mauricio Bustamante, Anna Nierenberg, Ashley Ross* .'],
#  [u'Open University',
#   u'Open University (w/ Clark) ( [http://jobregister.aas.org/job_view?JobID=47272 ad] )',
#   u'Deadline Feb. 28 2014.'],
#  [u'Open University',
#   u'Open University (w/ Haswell) ( [http://jobregister.aas.org/job_view?JobID=47274 ad] )',
#   u'Deadline Feb. 28 2014.'],
#  [u'Oxford - two Beecroft fellowships',
#   u'Oxford - two Beecroft fellowships ( [http://jobregister.aas.org/node/46092 ad] )',
#   u'due Dec. 1 2013, shortlist made, interviews scheduled, two offers made to Mark Richardson and *Elisa Chisari.*'],
#  [u'Oxford - postdoc position in dynamics',
#   u'Oxford - postdoc position in dynamics ( [https://www.recruit.ox.ac.uk/pls/hrislivedoc/docs/0009883726.pdf ad] )',
#   u'Deadline May 12 2014'],
#  [u'Oxford - Hintze Fellowship',
#   u'Oxford - Hintze Fellowship',
#   u'Interviews being scheduled.'],
#  [u'Penn State - cosmology HETDEX/eBOSS',
#   u'Penn State - cosmology HETDEX/eBOSS ( [http://jobregister.aas.org/job_view?JobID=46105 ad] )',
#   u'Offered to *Nishant Agarwal* .'],
#  [u'Penn State - Center for Exoplanets and Habitable Worlds',
#   u'Penn State - Center for Exoplanets and Habitable Worlds ( [http://jobregister.aas.org/job_view?JobID=45990 ad] )',
#   u'due Jan. 1, 2014. Offer made to *Thomas Beatty* .'],
#  [u'Perimeter',
#   u'Perimeter',
#   u'Offers made to Colin Hill (declined), *Stephen Green* .'],
#  [u'University of Pittsburgh - MaNGA Visualization',
#   u'University of Pittsburgh - MaNGA Visualization (w/Badenes, [http://jobregister.aas.org/job_view?JobID=46413 ad)]',
# ...
#   u'Shortlist includes Noelia Jim\xe9nez,Y. Rosas-Guevara'],
#  [u'STFC Rutherford Fellowship',
#   u'STFC Rutherford Fellowship',
#   u'Some candidates invited for interviews including Jens Chluba and Christoph Federrath (withdrawn). Offers made, including Izaskun Jimenez-Serra (UCL), *Timothy A. Davis (* *Hertfordshire)* , Caitriona Jackman ( Southampton)'],
#  [u'STSci',
#   u'STSci (/w Meixner, [https://rn11.ultipro.com/SPA1004/JobBoard/JobDetails.aspx?__ID=*638889591859873E ad] )',
#   u'due Feb. 28, 2014. Offer made to *Olivia Jones.*'],
#  [u'STSci',
#   u'STSci (/w Chen, [https://rn11.ultipro.com/SPA1004/JobBoard/JobDetails.aspx?__ID=*B0981FBE93478796 ad] )',
#   u'due Feb. 1, 2014.'],
#  [u'STSci',
#   u'STSci (RIA, [https://rn11.ultipro.com/SPA1004/JobBoard/JobDetails.aspx?__ID=*704C3D820D6BE438 ad] )',
#   u'due Feb. 28, 2014.'],
#  [u'Stromlo Fellow',
#   u'Stromlo Fellow ( [http://jobregister.aas.org/node/46025 ad] )',
#   u'shortlist made, offer made to Christoph Federrath.'],
#  [u'Subaru Fellowship, 3-5 year Research Associate',
#   u'Subaru Fellowship, 3-5 year Research Associate ( [http://jobregister.aas.org/job_view?JobID=46170 ad] )',
#   u'Short list made. Interviews scheduled. Offer made (1/19) *Thayne Currie* (with SCExAO).'],
#  [u'SUNY Stony Brook',
#   u'SUNY Stony Brook (w/ Perna) ( [http://jobregister.aas.org/job_view?JobID=45656 ad] )',
#   u'Shortlist made. Offer made: *Takamitsu Tanaka (joint with NYU)*'],
#  [u'Swinburne University',
#   u'Swinburne University (with Mould, Taipan)',
#   u'offer made.'],
#  [u'Swinburne University',
#   u'Swinburne University (with Mould, [http://jobregister.aas.org/job_view?JobID=47106 ad] )',
#   u'Shortlist made. Interviews being scheduled, including Michele Compostella (withdrawn), Matteo Tomassetti (withdrawn). Offer made (?)'],
#  [u'Technion - AstroTech fellowship',
#   u'Technion - AstroTech fellowship ( [http://jobregister.aas.org/job_view?JobID=45863 ad] )',
#   u'due Dec. 1, 2013'],
#  [u'Technion-China/India/Taiwan Fellowship',
#   u'Technion-China/India/Taiwan Fellowship ( [http://jobregister.aas.org/job_view?JobID=45863 ad] )',
#   u'due Oct. 25, 2013. Offer made to Vimal Simha.'],
#  [u'Universidad de Chile',
#   u'Universidad de Chile (with Escala and Cuadra, [http://jobregister.aas.org/node/46923 ad] )',
#   u'Some candidates interviewed week of 13 Jan. Offer made to Y. Rosas-Guevara(declined)'],
#  [u'Universidad de Concepcion',
#   u'Universidad de Concepcion (with Treister, [http://jobregister.aas.org/job_view?JobID=46219 ad] )',
#   u'Offer made and *accepted* .'],
#  [u'Universidad Diego Portales',
#   u'Universidad Diego Portales (UDP, Chile, [http://jobregister.aas.org/job_view?JobID=46444 ad] )',
#   u'Shorlist made. Interviews being scheduled (Jan. 14), including Jennifer Andrews, Rubab Khan. Offer made to Jennifer Andrews (declined). New offer made and *accepted* (02/19).'],
#  [u'University of Edinburgh', u'University of Edinburgh', u'due Dec. 10.'],
#  [u'University of Edinburgh',
#   u'University of Edinburgh (w/ Biller, [http://jobregister.aas.org/job_view?JobID=47330 ad] )',
#   u'due Feb. 24, 2014.'],
#  [u'Universit\xe9 de Montr\xe9al, Observational Astrophysics',
#   u'Universit\xe9 de Montr\xe9al, Observational Astrophysics (w/ Hlavacek-Larrondo, [http://jobregister.aas.org/job_view?JobID=46645 ad] )',
#   u'due Jan. 31, 2014.'],
#  [u'University of Texas at Austin',
#   u'University of Texas at Austin (IGRINS Postdoctoral Fellow w/ Jaffe, [http://jobregister.aas.org/job_view?JobID=46752 ad] )',
#   u'Offer accepted by *Gregory Mace* .'],
#  [u'University of Texas at Austin',
#   u'University of Texas at Austin (w/ Finkelstein, [http://jobregister.aas.org/job_view?JobID=45993 ad] )',
#   u'AAS interviews, including Stacey Alberts, Christina Williams. Offer accepted by Isak Wold .'],
#  [u'University of Texas at Austin, McDonald Fellowship',
#   u'University of Texas at Austin, McDonald Fellowship ( [http://jobregister.aas.org/job_view?JobID=45593 ad] )',
#   u'due Nov. 25, 2013. Shortlist includes Stacey Alberts, Christina Williams, Johanna Teske. Offer made to *Natalie Gosnell* . Offer made to Anne Jaskot (declined).'],
#  [u'LEAP PostDoc University of St Andrews',
#   u'LEAP PostDoc University of St Andrews ( [https://www.vacancies.st-andrews.ac.uk/ViewVacancy.aspx?enc=mEgrBL4XQK0+ld8aNkwYmL81sObiUzXbXizaxOgbD+9DmmyFqs2KJe5+zqYyYUnRhJKKe7c4hb9XNzyhwOjw+tX8B80+A7+uNT9ZVTXjnfmuxrHLPAjlY6vlyLrT9baH ad] )',
#   u'due Oc t. 30, 2013.'],
#  [u'University of Maryland with Boylan-Kolchin',
#   u'University of Maryland with Boylan-Kolchin( [http://jobregister.aas.org/job_view?JobID=45748 ad] )',
#   u'Offer accepted by *Brandon Bozek* .'],
#  [u'University of Maryland with Jonathan McKinney',
#   u'University of Maryland with Jonathan McKinney ( [http://jobregister.aas.org/job_view?JobID=46590 ad] )',
#   u'Offer made to *Jane Lixin Dai* .'],
#  [u'University of Maryland',
#   u'University of Maryland (TCAN w/ Reynolds, [http://jobregister.aas.org/node/45695 ad] )',
#   u'Offer made to *Brian Morsony* .'],
#  [u'UMAss Amherst with Wang',
#   u'UMAss Amherst with Wang ( [http://umass.interviewexchange.com/jobofferdetails.jsp;jsessionid=0DA7125A1FF866955738314D20588C3D?JOBID=44556 ad] )',
#   u'Offer made to Tyler Desjardins (declined 2/18)'],
#  [u'University of Michigan with Bergin',
#   u'University of Michigan with Bergin ( [http://jobregister.aas.org/job_view?JobID=46337 ad] )',
#   u'due Dec. 15. Shortlist made (?) Offer to *Nick Indriolo*'],
#  [u'University of Michigan with Bregman',
#   u'University of Michigan with Bregman ( [http://jobregister.aas.org/node/46321 ad] )',
#   u'due Dec 20'],
#  [u'University of Michigan in Ann Arbor',
#   u'University of Michigan in Ann Arbor (theoretical/computational astrophysics, /w Ruszkowski, [http://jobregister.aas.org/node/45794 ad] )',
#   u'due Jan. 1, 2014. Shortlist to be made by 01/31/14, offer made to *Yuan Li*'],
#  [u'University of Michigan, cosmology',
#   u'University of Michigan, cosmology (Physics Dept, w/ Huterer, [https://academicjobsonline.org/ajo/jobs/3607 ad] )',
#   u'(580 total applications for all particle/cosmo jobs). No offers this year.'],
#  [u'University of Michigan in Ann Arbor, extragalactic astrophysics and gravitational lensing',
#   u'University of Michigan in Ann Arbor, extragalactic astrophysics and gravitational lensing (Astronomy Dept., w/Sharon) ( [http://jobregister.aas.org/job_view?JobID=46221 ad] )',
#   u'due Jan. 3, 2014. Offer made to Curtis McCully.'],
#  [u'University of North Carolina, theoretical cosmology',
#   u'University of North Carolina, theoretical cosmology (w/Erickcek, [https://unc.peopleadmin.com/postings/38519 ad)]',
#   u'Review of applications begins March 10, 2014.'],
#  [u'University of California, Davis',
#   u'University of California, Davis (with Fassnacht, [http://jobregister.aas.org/node/46761 ad] )',
#   u'Offer made to Curtis McCully, *Cristian Eduard Rusu*'],
#  [u'University of California, Irvine',
#   u'University of California, Irvine (with Cooray, [http://jobregister.aas.org/job_view?JobID=45518 ad] )',
#   ''],
#  [u'University of California, Santa Barbara & LCOGT',
#   u'University of California, Santa Barbara & LCOGT (with Howell, [http://jobregister.aas.org/node/46462 ad] )',
#   u'Offer made to *Curtis McCully* .'],
#  [u'University of California, Santa Cruz',
#   u'University of California, Santa Cruz (star formation, with Krumholz, [https://recruit.ucsc.edu/apply/JPF00068 ad] )',
#   u'due Dec. 15, 2013. Offer made to *Chalence Safranek-Shrader* .'],
#  [u'University of California, Santa Cruz',
#   u'University of California, Santa Cruz (computational stellar spectroscopy w/ Conroy, [https://recruit.ucsc.edu/apply/JPF00076 ad] )',
#   u'shortlist made'],
#  [u'University of Chicago - EFI, Fermi and McCormick Fellowships',
#   u'University of Chicago - EFI, Fermi and McCormick Fellowships ( [http://fermi-mccormick-fellow.uchicago.edu ad] )',
#   u'McCormick Fellowship offered to *Ben Farr* . Vinu Vikram (U. Chicago KICP + FermiLab fellowship offered)'],
#  [u'University of Chicago - KICP Fellowship',
#   u'University of Chicago - KICP Fellowship ( [http://kicp-fellowship.uchicago.edu/ a] d)',
#   u'Offers made to Tijmen de Haan (declinded), *Dan Scolnic* , *Silvia Galli* .'],
#  [u'University College London',
#   u'University College London (cosmology, with Peiris, [http://tinyurl.com/UCLcosmologypostdoc ad] )',
#   u'Shortlist includes Nishant Agarwal, Daan Meerburg, Silvia Galli. Interviews are being scheduled. Offered to Daan Meerburg, *Jonathan Braden* .'],
#  [u'University College London',
#   u'University College London (cosmology - 2 positions, with Peiris & Joachimi, [https://atsv7.wcn.co.uk/search_engine/jobs.cgi?amNvZGU9MTQwMTI5NyZ2dF90ZW1wbGF0ZT05NjUmb3duZXI9NTA0MTE3OCZvd25lcnR5cGU9ZmFpciZicmFuZF9pZD0wJnBvc3RpbmdfY29kZT0yMjQmcmVxc2lnPTEzOTIyODMwMTYtOGZmM2E5OWMyMGJkYmM1NzJjNzkxNjgxODBkN2FlNThiMzFiNTk4MQ%3D%3D&jcode=1401297&vt_template=965&owner=5041178&ownertype=fair&brand_id=0&posting_code=224&reqsig=1392283016-8ff3a99c20bdbc572c79168180d7ae58b31b5981 ad] )',
#   u'Due March 16th. Offered to *Edo van Uitert* .'],
#  [u'University of Geneva',
#   u'University of Geneva (with Kunz, [http://cosmology.unige.ch/content/postdoctoral-position-theoretical-cosmology ad] )',
#   u'Offered to Alvise Raccanelli (declined). Offer made to other candidate (accepted).'],
#  [u'University of Geneva',
#   u'University of Geneva (with Schaerer, [http://jobregister.aas.org/node/47472 ad] )',
#   u'Shortlist made includes Jamie Ownsworth'],
#  [u'University of Hertfordshire',
#   u'University of Hertfordshire ( [http://jobregister.aas.org/job_view?JobID=46660 ad] )',
#   u'About ~90 applications received. Interviews being scheduled (Feb 22). Two offers made and *accepted.*'],
#  [u'University of Hong Kong',
#   u'University of Hong Kong (w/ M.H. Lee, [http://jobregister.aas.org/node/46775 ad] )',
#   u'Due Dec. 31st'],
#  [u'University of Illinois',
#   u'University of Illinois (w/ Foley, [http://jobregister.aas.org/node/46441 ad] )',
#   u'Offer made to Curtis McCully.'],
#  [u'University of Leeds',
#   u'University of Leeds (with Hoare, [http://jobregister.aas.org/job_view?JobID=47309 ad] )',
#   u'Due Feb 9th'],
#  [u'University of Leeds',
#   u'University of Leeds (4 positions in star formation, [http://jobregister.aas.org/job_view?JobID=47304 ad] )',
#   u'Shortlists made for some positions. Interviews scheduled and (all?) held. MAPPA0048 position (see ad): *Katharine Johnston.*'],
#  [u'University of Leicester',
#   u'University of Leicester (with Alexander, [http://jobregister.aas.org/job_view?JobID=46687 ad] )',
#   u'Shortlist made, phone interviews scheduled'],
#  [u'University of Leicester',
#   u'University of Leicester (with King, [http://jobregister.aas.org/job_view?JobID=46687 ad] )',
#   u'Offer made to *Stuart Muldrew*'],
#  [u'University of Mississippi',
#   u'University of Mississippi (gravitational-wave astronomy, [http://www.phy.olemiss.edu/GR/?x=entry:entry131007-123804 ad] )',
#   u'due Dec. 31, 2013 (preferably earlier).'],
#  [u'University of Manchester',
#   u'University of Manchester (w/ Battye, [http://jobregister.aas.org/job_view?JobID=47281 ad] )',
#   u'due Jan. 31, 2014. Short list made, including Stefano Camera.'],
#  [u'University of Manchester',
#   u'University of Manchester (w/ Brown, [http://jobregister.aas.org/job_view?JobID=47286 ad] )',
#   u'due Jan. 31, 2014. Short list made, including Stefano Camera. Offer made and accepted *Stefano Camera* .'],
#  [u'University of Manchester',
#   u'University of Manchester (Instrumentation, [http://jobregister.aas.org/job_view?JobID=47288 ad] )',
#   u'due Jan. 31, 2014'],
#  [u'University of Manchester',
#   u'University of Manchester (w/ Jackson, [http://jobregister.aas.org/job_view?JobID=47265 ad] )',
#   u'due Jan. 31, 2014. Short list made, including Stefano Camera and Zuzanna Kostrzewa-Rutkowska.'],
#  [u'University of Manchester',
#   u'University of Manchester (w/ Kay, [http://jobregister.aas.org/node/47284 ad] )',
#   u'Shortlist made, interviews scheduled'],
#  [u'University of Nottingham',
#   u'University of Nottingham (with Almaini, [http://jobregister.aas.org/job_view?JobID=46782 ad] )',
#   u'Shortlist includes Tim Weinzirl. Offer made and *accepted*'],
#  [u'University of Nottingham',
#   u'University of Nottingham (with Aragon-Salamanca and Gray, [http://jobregister.aas.org/job_view?JobID=46798 ad] )',
#   u'Shortlist made, interviews being scheduled. Shortlist includes Tim Weinzirl, Caterina Lani, Asmus Boehm. Offer made to *Tim Weinzirl* .'],
#  [u'University of Portsmouth ICG,',
#   u'University of Portsmouth ICG, (ref. 310 with Koyama) ( [http://inspirehep.net/record/1266328 ad] )',
#   u'due Jan. 3, 2014. Any news? offer made and *accepted* (~Jan 14)'],
#  [u'University of Portsmouth ICG, 3 positions',
#   u'University of Portsmouth ICG, 3 positions (ref. 308, 309 and 312) ( [http://inspirehep.net/record/1268422 ad] )',
#   u'due Jan. 10, 2014. Interviews are being scheduled, including Jennifer Andrews and Stefano Camera. One offer made to *Thomas Tram* . Offered to Vinu Vikram, ....'],
#  [u'University of Southampton',
#   u'University of Southampton (refs 318613WF & 331713WF , w/ Sullivan) ( [http://jobregister.aas.org/job_view?JobID=46860 ad] , [http://jobregister.aas.org/node/47260 ad] )',
#   u'due Jan 6th & Jan 31st: Some interviews being scheduled, including Jennifer Andrews, Sandra Benitez-Herrera, Zuzanna Kostrzewa-Rutkowska; more to follow.'],
#  [u'University of Szczecin',
#   u'University of Szczecin (exoplanets stability)',
#   u'due Jan 10, 2014. Shortlist includes Trifon Trifonov.'],
#  [u'University of Utah',
#   u'University of Utah(eBOSS operations/SDSS-IV, [http://jobregister.aas.org/job_view?JobID=45873 ad] )',
#   u'Offer made and accepted by *Julian Bautista* .'],
#  [u'Virginia Tech',
#   u'Virginia Tech (theoretical astroparticle physics) ( [http://inspirehep.net/record/1265718 ad] )',
#   u'Offer made to Mauricio Bustamante (declined). Position *filled* .'],
#  [u'Virginia Tech',
#   u'Virginia Tech (quasars/AGN, [http://jobregister.aas.org/job_view?JobID=45484 ad] )',
#   u'Interviews underway, including Guilin Liu. Offer made to Guilin Liu.'],
#  [u'University of Washington',
#   u'University of Washington (with McQuinn) ( [http://faculty.washington.edu/mcquinn/AASAdMcQuinn.pdf ad] )',
#   u"Letters requested from 10 people (1/21), including Michele Compostella, David Syphers, Matteo Tomassetti, Amanda Ford. Offer made to Anson D'Aloisio ."],
#  [u'University of Washington',
#   u'University of Washington (with Wallerstein, [http://jobregister.aas.org/job_view?JobID=46250 ad] )',
#   ''],
#  [u'University of Wyoming',
#   u'University of Wyoming (with Myers, [http://jobregister.aas.org/job_view?JobID=46623 ad] )',
#   u'Interviews underway, including Guilin Liu.'],
#  [u'Wesleyan University',
#   u'Wesleyan University (exoplanets, with Redfield, [http://jobregister.aas.org/job_view?JobID=45853 ad] )',
#   u'due Dec. 13, 2013'],
#  [u"Michael West Research Fellowship - Queen's University Belfast",
#   u"Michael West Research Fellowship - Queen's University Belfast ( [http://jobregister.aas.org/node/46201 ad] )",
#   u'Several interviews being scheduled. Short list includes Jennifer Andrews. Offer made'],
#  [u'West Virginia University',
#   u'West Virginia University (w/ Etienne) [http://hyperspace.aei.mpg.de/2014/01/22/postdoctoral-research-associate-in-numerical-relativity-or-computational-astrophysics-at-west-virginia-university/ (ad)]',
#   u'due Mar. 1, 2014'],
#  [u'University of Zagreb',
#   u'University of Zagreb (w/ Smolcic) [http://jobregister.aas.org/node/45540 (ad)]',
#   u'*Oskari Miettinen* , offer made to Jacinta Delhaize'],
#  [u'Yale YCAA Prize Fellowship',
#   u'Yale YCAA Prize Fellowship ( [http://jobregister.aas.org/job_view?JobID=45673 ad] )',
#   u'Offer made and accepted. Rejections sent.'],
#  [u'Yale',
#   u'Yale (Theoretical and Computational Astrophysics Network; massive black hole formation) ( [http://jobregister.aas.org/job_view?JobID=45702 ad] )',
#   u'offer made to *Bhaskar Agarwal*'],
#  [u'University of Zurich',
#   u'University of Zurich (ITP, [http://jobregister.aas.org/node/46518 ad] )',
#   u'Offers made to Florent Renaud (declined), Sijing Shen.']]

# %%
print data[-1]['version']
print BeautifulSoup(data[-1]['preview']).find('table').find_all('td')[3].prettify()
# ['\n'.join(x['changes']) for x in data[1:]]
# Out:
# 1171
# <td class="wikicell" width="434">
#  due Dec. 15, 2013. Offer made to
#  <strong>
#   Else Starkenburg
#  </strong>
# </td>
